# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
import math
from imgaug import augmenters as iaa
sns.set(style="darkgrid", font_scale=1.0)
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import io 
import pandas as pd

from tensorflow import keras
from keras.models import load_model
from keras.utils import plot_model
from keras import regularizers
from keras.callbacks import LearningRateScheduler

from keras import backend as K

# %%
# print version number
print(tf.__version__)
# Out:
# 2.3.0

# %%
# check GPU specs
# !nvidia-smi
# Out:
# Wed Oct 28 11:52:56 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.23.05    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8     8W /  75W |      0MiB /  7611MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# dataset normalization

def normalization(mode, x):
  # normalize using mean and standard deviation
  mean, std = x.mean(), x.std()  
  x = (x - mean) / std  

  return x

# %%
img_width, img_height = 32, 32

# handle image format
if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:
    input_shape = (img_width, img_height, 3)

# download cifar data and split into train and test sets
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

# normalizing and scaling by pixels
x_train = normalization('mean', x_train)
x_test = normalization('mean', x_test)
x_train = x_train / 255.0
x_test = x_test / 255.0

class_names = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck']

# %%
# image augmentation
seq = iaa.Sequential([
  iaa.Fliplr(0.5),
  iaa.Sometimes(
      0.5,
      iaa.GaussianBlur(sigma=(0, 0.5))
  )
], random_order=True)

# append augmented images to dataset to increase dataset size
aug_img = seq.augment_images(x_train)
x_train = np.append(x_train, aug_img, axis=0)
y_train = np.append(y_train, y_train, axis=0)

print("Dataset size:", x_train.shape, "Label size:", y_train.shape)
# Out:
# Dataset size: (100000, 32, 32, 3) Label size: (100000, 1)

# %%
class LearningRate(tf.keras.callbacks.Callback):
  
  def on_train_begin(self,logs={}):
    self.lr_epoch=[]

  def on_epoch_end(self, batch, logs={}):
    self.lr_epoch.append(step_decay(len(self.lr_epoch)+1, weight_decay))
		
def step_decay(epoch, initial_lrate):
	drop = 0.05
	epochs_drop = 30
	lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
	return lrate

# %%
def model_(model_type):
  if model_type is 'A':
    # Network for Part A
    model = keras.Sequential([    
      # Stage 1                    
      keras.layers.Conv2D(filters=32, kernel_size=5, padding='same', activation='relu', input_shape=input_shape),
      keras.layers.MaxPooling2D(pool_size=(2,2), padding='same', strides=2),  
      keras.layers.BatchNormalization(),
      # Stage 2
      keras.layers.ZeroPadding2D(padding=(1, 1)),
      keras.layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu', input_shape=input_shape),
      keras.layers.MaxPooling2D(pool_size=(2,2), padding='same', strides=2),  
      keras.layers.BatchNormalization(),
      # Stage 3
      keras.layers.ZeroPadding2D(padding=(1, 1)),
      keras.layers.Conv2D(filters=128, kernel_size=3, padding='same', activation='relu', input_shape=input_shape),
      keras.layers.MaxPooling2D(pool_size=(2,2), padding='same', strides=2),  
      keras.layers.BatchNormalization(),
      # FC - Output
      keras.layers.Flatten(),
      keras.layers.Dense(500),
      keras.layers.Dropout(0.5),
      keras.layers.Dense(10, activation=tf.nn.softmax)
    ])

  if model_type is 'B':
    # Network for Part B
    model = keras.Sequential([    
      # Stage 1                        
      keras.layers.Conv2D(filters=32, kernel_size=5, padding='same', activation='relu', input_shape=input_shape),
      keras.layers.MaxPooling2D(pool_size=(2,2), padding='same', strides=2),  
      keras.layers.BatchNormalization(),
      # Stage 2
      keras.layers.ZeroPadding2D(padding=(1, 1)),
      keras.layers.Conv2D(filters=32, kernel_size=1, padding='same', activation='relu', input_shape=input_shape),
      keras.layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu', input_shape=input_shape),
      keras.layers.Conv2D(filters=64, kernel_size=1, padding='same', activation='relu', input_shape=input_shape),
      keras.layers.MaxPooling2D(pool_size=(2,2), padding='same', strides=2),  
      keras.layers.BatchNormalization(),
      # Stage 3
      keras.layers.ZeroPadding2D(padding=(1, 1)),
      keras.layers.Conv2D(filters=64, kernel_size=1, padding='same', activation='relu', input_shape=input_shape),
      keras.layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu', input_shape=input_shape),
      keras.layers.Conv2D(filters=128, kernel_size=1, padding='same', activation='relu', input_shape=input_shape),
      keras.layers.MaxPooling2D(pool_size=(2,2), padding='same', strides=2),  
      keras.layers.BatchNormalization(),
      keras.layers.GlobalAveragePooling2D(),
      # FC - Output
      keras.layers.Flatten(),
      keras.layers.Dense(500),
      keras.layers.Dropout(0.5),
      keras.layers.Dense(10, activation=tf.nn.softmax)
    ])

  if model_type is 'C':
    # Network for Part C
    model = keras.Sequential([    
      # Stage 1
      keras.layers.Conv2D(filters=32, kernel_size=5, padding='same', activation='relu', input_shape=input_shape),
      keras.layers.MaxPooling2D(pool_size=(2,2), padding='same', strides=2),  
      keras.layers.BatchNormalization(),
      # Stage 2
      keras.layers.ZeroPadding2D(padding=(1, 1)),
      keras.layers.SeparableConv2D(filters=64, kernel_size=3, padding='same', activation='relu', input_shape=input_shape),
      keras.layers.MaxPooling2D(pool_size=(2,2), padding='same', strides=2),  
      keras.layers.BatchNormalization(),
      # Stage 3
      keras.layers.ZeroPadding2D(padding=(1, 1)),
      keras.layers.SeparableConv2D(filters=128, kernel_size=3, padding='same', activation='relu', input_shape=input_shape),
      keras.layers.MaxPooling2D(pool_size=(2,2), padding='same', strides=2),  
      keras.layers.BatchNormalization(),
      # FC - Output
      keras.layers.Flatten(),
      keras.layers.Dense(500),
      keras.layers.Dropout(0.5),
      keras.layers.Dense(10, activation=tf.nn.softmax)
    ])

  return model

# %%
epochs = 50
batch_size = 64
weight_decay = 0.001
model = model_('B')

lr_history=LearningRate()
lrate = LearningRateScheduler(step_decay, weight_decay)
callbacks_list = [lr_history,lrate]
model.compile(optimizer=tf.keras.optimizers.SGD(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

start_time = time.time()
model.summary()
train_model = model.fit(x_train, y_train, epochs=epochs, validation_data=(x_test, y_test), batch_size=batch_size, callbacks=callbacks_list, shuffle=True)
time_taken = time.time() - start_time
print('Time taken for %d epochs: %.4f' % (epochs, time_taken))

test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test accuracy: {:5.2f}%'.format(100 * test_acc))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        2432
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 16, 16, 32)        128
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 18, 18, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 18, 32)        1056
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 18, 18, 32)        9248
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 64)        2112
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 9, 64)          0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 9, 9, 64)          256
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 11, 11, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 11, 11, 64)        4160
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 11, 11, 64)        36928
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 11, 11, 128)       8320
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 6, 6, 128)         512
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 500)               2304500
# _________________________________________________________________
# dropout (Dropout)            (None, 500)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 2,374,662
# Trainable params: 2,374,214
# Non-trainable params: 448
# _________________________________________________________________
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 1/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.5440 - accuracy: 0.4449 - val_loss: 1.9177 - val_accuracy: 0.3548
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 2/50
# 1563/1563 [==============================] - 9s 5ms/step - loss: 1.2253 - accuracy: 0.5647 - val_loss: 1.2520 - val_accuracy: 0.5511
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 3/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.0839 - accuracy: 0.6164 - val_loss: 1.3119 - val_accuracy: 0.5549
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 4/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.9933 - accuracy: 0.6530 - val_loss: 1.3576 - val_accuracy: 0.5389
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 5/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.9213 - accuracy: 0.6771 - val_loss: 1.3199 - val_accuracy: 0.5593
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 6/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8652 - accuracy: 0.6956 - val_loss: 1.2515 - val_accuracy: 0.5739
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 7/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8202 - accuracy: 0.7130 - val_loss: 1.4467 - val_accuracy: 0.5485
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 8/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7790 - accuracy: 0.7268 - val_loss: 0.9525 - val_accuracy: 0.6703
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 9/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7430 - accuracy: 0.7391 - val_loss: 2.2113 - val_accuracy: 0.4548
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 10/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7108 - accuracy: 0.7509 - val_loss: 1.1357 - val_accuracy: 0.6360
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 11/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6838 - accuracy: 0.7596 - val_loss: 1.3155 - val_accuracy: 0.5729
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 12/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6590 - accuracy: 0.7684 - val_loss: 1.1974 - val_accuracy: 0.6220
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 13/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.6349 - accuracy: 0.7780 - val_loss: 0.9524 - val_accuracy: 0.6864
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 14/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.6096 - accuracy: 0.7853 - val_loss: 1.2358 - val_accuracy: 0.6147
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 15/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5902 - accuracy: 0.7943 - val_loss: 1.1802 - val_accuracy: 0.6435
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 16/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5676 - accuracy: 0.8001 - val_loss: 0.9993 - val_accuracy: 0.6860
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 17/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5524 - accuracy: 0.8075 - val_loss: 0.9569 - val_accuracy: 0.6906
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 18/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5316 - accuracy: 0.8114 - val_loss: 1.2323 - val_accuracy: 0.6424
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 19/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5188 - accuracy: 0.8175 - val_loss: 1.0660 - val_accuracy: 0.6783
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 20/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.4997 - accuracy: 0.8235 - val_loss: 1.2359 - val_accuracy: 0.6427
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 21/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.4864 - accuracy: 0.8287 - val_loss: 0.9651 - val_accuracy: 0.6987
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 22/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.4718 - accuracy: 0.8339 - val_loss: 1.1478 - val_accuracy: 0.6687
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 23/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.4573 - accuracy: 0.8398 - val_loss: 1.0624 - val_accuracy: 0.6928
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 24/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.4439 - accuracy: 0.8429 - val_loss: 0.9379 - val_accuracy: 0.7152
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 25/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.4355 - accuracy: 0.8458 - val_loss: 1.0472 - val_accuracy: 0.6913
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 26/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.4190 - accuracy: 0.8522 - val_loss: 1.1730 - val_accuracy: 0.6708
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 27/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.4181 - accuracy: 0.8523 - val_loss: 1.1289 - val_accuracy: 0.6818
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 28/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.4139 - accuracy: 0.8541 - val_loss: 1.1066 - val_accuracy: 0.6711
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 29/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.4011 - accuracy: 0.8580 - val_loss: 1.1386 - val_accuracy: 0.6783
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0004999999888241291.
# Epoch 30/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.3110 - accuracy: 0.8930 - val_loss: 0.9571 - val_accuracy: 0.7211
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 2.4999998277053238e-05.
# Epoch 31/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2898 - accuracy: 0.9020 - val_loss: 0.9562 - val_accuracy: 0.7212
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.249999877472874e-06.
# Epoch 32/50
# 1563/1563 [==============================] - 9s 5ms/step - loss: 0.2898 - accuracy: 0.9020 - val_loss: 0.9535 - val_accuracy: 0.7216
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 6.249999273677531e-08.
# Epoch 33/50
# 1563/1563 [==============================] - 9s 5ms/step - loss: 0.2907 - accuracy: 0.9017 - val_loss: 0.9539 - val_accuracy: 0.7222
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 3.124999636838766e-09.
# Epoch 34/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2904 - accuracy: 0.9019 - val_loss: 0.9548 - val_accuracy: 0.7210
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 1.5624997962149225e-10.
# Epoch 35/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2908 - accuracy: 0.9011 - val_loss: 0.9545 - val_accuracy: 0.7214
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 7.812499258630368e-12.
# Epoch 36/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2898 - accuracy: 0.9023 - val_loss: 0.9533 - val_accuracy: 0.7220
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 3.9062494558428364e-13.
# Epoch 37/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2890 - accuracy: 0.9026 - val_loss: 0.9525 - val_accuracy: 0.7211
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 1.9531247550264727e-14.
# Epoch 38/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.2902 - accuracy: 0.9008 - val_loss: 0.9550 - val_accuracy: 0.7222
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 9.765624113945542e-16.
# Epoch 39/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2903 - accuracy: 0.9016 - val_loss: 0.9556 - val_accuracy: 0.7211
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 4.8828119510936526e-17.
# Epoch 40/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2902 - accuracy: 0.9021 - val_loss: 0.9535 - val_accuracy: 0.7212
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.4414060417212753e-18.
# Epoch 41/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2902 - accuracy: 0.9017 - val_loss: 0.9550 - val_accuracy: 0.7216
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 1.2207030001811222e-19.
# Epoch 42/50
# 1563/1563 [==============================] - 9s 5ms/step - loss: 0.2897 - accuracy: 0.9022 - val_loss: 0.9540 - val_accuracy: 0.7219
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 6.1035150009056115e-21.
# Epoch 43/50
# 1563/1563 [==============================] - 9s 5ms/step - loss: 0.2909 - accuracy: 0.9005 - val_loss: 0.9540 - val_accuracy: 0.7220
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 3.0517574600631274e-22.
# Epoch 44/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2920 - accuracy: 0.9009 - val_loss: 0.9531 - val_accuracy: 0.7225
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 1.5258787552751125e-23.
# Epoch 45/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2907 - accuracy: 0.9015 - val_loss: 0.9551 - val_accuracy: 0.7214
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 7.629394091919926e-25.
# Epoch 46/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2903 - accuracy: 0.9018 - val_loss: 0.9543 - val_accuracy: 0.7219
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 3.8146971445675756e-26.
# Epoch 47/50
# 1563/1563 [==============================] - 9s 5ms/step - loss: 0.2916 - accuracy: 0.9009 - val_loss: 0.9540 - val_accuracy: 0.7214
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 1.9073485722837878e-27.
# Epoch 48/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2896 - accuracy: 0.9015 - val_loss: 0.9549 - val_accuracy: 0.7211
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 9.536742861418939e-29.
# Epoch 49/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2906 - accuracy: 0.9015 - val_loss: 0.9543 - val_accuracy: 0.7215
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 4.76837143070947e-30.
# Epoch 50/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.2900 - accuracy: 0.9023 - val_loss: 0.9541 - val_accuracy: 0.7214
# Time taken for 50 epochs: 425.5661
# 313/313 [==============================] - 1s 3ms/step - loss: 0.9541 - accuracy: 0.7214
# Test accuracy: 72.14%

# %%
# logging and history

# get model summary string to be saved as text file
def get_model_summary(model):
  stream = io.StringIO()
  model.summary(print_fn=lambda x: stream.write(x + '\n'))
  summary_string = stream.getvalue()
  stream.close()
  return summary_string

model_summary_string = get_model_summary(model)
hist_df = pd.DataFrame(train_model.history)

# write history to log text file
file = open(r'drive/My Drive/log.txt', 'w')
file.write("Model summary: \n" + str(model_summary_string))
file.write("Number of Epochs: %d, Batch Size: %d" %(epochs, batch_size))
file.write("\n History: \n" + str(hist_df))
file.write(str("\nTime taken: %.4f," %((time_taken)) + ' Test accuracy: {:5.2f}%'.format(100 * test_acc)))
file.close()

# %%
# Save entire model to a HDF5 file
model.save('drive/My Drive/model.h5')
print('Model saved.')
# Out:
# Model saved.

# %%
# plot accuracy and loss of model in a graph
history = train_model.history
history.keys()

acc = history['accuracy']
val_acc = history['val_accuracy']
loss = history['loss']
val_loss = history['val_loss']

epochs_no = range(1, len(acc) + 1)

# "bo" is for "blue dot"
plt.plot(epochs_no, loss, 'ro', label='Training loss')
# b is for "solid blue line"
plt.plot(epochs_no, val_loss, 'r', label='Testing loss')
# "bo" is for "blue dot"
plt.plot(epochs_no, acc, 'bo', label='Training accuracy')
# b is for "solid blue line"
plt.plot(epochs_no, val_acc, 'b', label='Testing accuracy')
plt.title('Graph of loss/accuracy vs number of epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss/Accuracy')
plt.legend()
plt.ylim(0.0, 3.0)

# save graph and show
plt.savefig('drive/My Drive/model.png')
plt.show()
