# %%
# prepare training and testing data

# %%
# getting folders of images and saving them into train and test arrays

import os

train_location = 'drive/My Drive/NN_Assignment/downsized/train'
test_location = 'drive/My Drive/NN_Assignment/downsized/test'
train_list = []
test_list = []

# save train and test directories in a list, sorted alphabetically
for train_dir in os.listdir(train_location):
  train_list.append(train_dir)
train_list = sorted(train_list)
for test_dir in os.listdir(test_location):
  test_list.append(test_dir)
test_list = sorted(test_list)

# check if training list is equals to testing list
print(train_list == test_list)
# Out:
# True

# %%
import cv2
from tqdm import tqdm
import os
import random
import numpy as np
from sklearn.externals import joblib

img_cols, img_rows = 32, 32

# prepare training data
train_location = 'drive/My Drive/NN_Assignment/downsized/train'
training_data = []
x_train = []
y_train = []

def create_train_data():
  for data in train_list:
    path = os.path.join(train_location, data)
    class_num = train_list.index(data)
    
    # iterate over images by directories alphabetically
    for img in tqdm(os.listdir(path)):
      try:
        img_array = cv2.imread(os.path.join(path,img))  # convert to array
        new_array = cv2.resize(img_array, (img_cols, img_rows))  # resize to normalize data size
        training_data.append([new_array, class_num])  # add this to our training_list
      except Exception as e: 
        pass
  return training_data

training_data = create_train_data()

random.shuffle(training_data)
for features,label in training_data:
  x_train.append(features)
  y_train.append(label)
x_train = np.array(x_train).reshape(len(training_data), img_rows, img_cols, 3)
y_train = np.array(y_train).reshape(len(training_data))

# save data in pickle file
joblib.dump(x_train, "x_train.pkl")
joblib.dump(y_train, "y_train.pkl")

# %%
# prepare testing data
test_location = 'drive/My Drive/NN_Assignment/downsized/test'
testing_data = []
x_test = []
y_test = []

def create_test_data():
  for data in test_list:
    path = os.path.join(test_location, data)
    class_num = test_list.index(data)
    
    # iterate over images by directories alphabetically
    for img in tqdm(os.listdir(path)):
      try:
        img_array = cv2.imread(os.path.join(path,img))  # convert to array
        new_array = cv2.resize(img_array, (img_cols, img_rows))  # resize to normalize data size
        testing_data.append([new_array, class_num])  # add this to our testing_list
      except Exception as e: 
        pass
  return testing_data

testing_data = create_test_data()

for features,label in testing_data:
  x_test.append(features)
  y_test.append(label)
x_test = np.array(x_test).reshape(len(testing_data), img_rows, img_cols, 3)
y_test = np.array(y_test).reshape(len(testing_data))

# save data in pickle file
joblib.dump(x_test, "x_test.pkl")
joblib.dump(y_test, "y_test.pkl")

# %%
# load CIFAR trained weights
weights_path = 'drive/My Drive/NN_Assignment/Weights/cifar.h5'

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:0 -> device: XLA_GPU device
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7

# %%
# define the model to fine-tune and begin training

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from keras.models import load_model
from keras.utils import plot_model
from keras import regularizers
from imgaug import augmenters as iaa
import cv2
from keras import backend as K
from sklearn.externals import joblib

epochs = 50
batch_size = 64
img_width, img_height = 32, 32
weight_decay = 0.00005

if K.image_data_format() == 'channels_first':
  input_shape = (3, img_width, img_height)
else:
  input_shape = (img_width, img_height, 3)

def create_functional_model():
  model = keras.Sequential([    
  keras.layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu', input_shape=input_shape),
  keras.layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'),
  keras.layers.MaxPooling2D(pool_size=(2,2)),  
  keras.layers.BatchNormalization(),
  
  keras.layers.Conv2D(filters=128, kernel_size=3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay)),
  keras.layers.Conv2D(filters=128, kernel_size=3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay)),
  keras.layers.MaxPooling2D(pool_size=(2,2)),  
  
  keras.layers.Conv2D(filters=256, kernel_size=3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay)),
  keras.layers.Conv2D(filters=256, kernel_size=3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay)),
  keras.layers.Conv2D(filters=256, kernel_size=3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay)),
  keras.layers.MaxPooling2D(pool_size=(2,2)),
  keras.layers.BatchNormalization(),
  
  keras.layers.Conv2D(filters=512, kernel_size=3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay)),
  keras.layers.Conv2D(filters=512, kernel_size=3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay)),
  keras.layers.Conv2D(filters=512, kernel_size=3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay)),
  keras.layers.MaxPooling2D(pool_size=(2,2)),
  keras.layers.BatchNormalization(),
  
  keras.layers.Conv2D(filters=512, kernel_size=3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay)),
  keras.layers.Conv2D(filters=512, kernel_size=3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay)),
  keras.layers.Conv2D(filters=512, kernel_size=3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay)),
  keras.layers.MaxPooling2D(pool_size=(2,2)),
  keras.layers.BatchNormalization(),

  keras.layers.Flatten(),
  keras.layers.Dense(512, activation=tf.nn.relu),
  keras.layers.Dropout(0.5),   
  keras.layers.Dense(10, activation=tf.nn.softmax)
  ])
  return model

pretrained_model = create_functional_model()
pretrained_model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_52 (Conv2D)           (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 32, 32, 64)        36928
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_54 (Conv2D)           (None, 16, 16, 128)       73856
# _________________________________________________________________
# conv2d_55 (Conv2D)           (None, 16, 16, 128)       147584
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_56 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# conv2d_57 (Conv2D)           (None, 8, 8, 256)         590080
# _________________________________________________________________
# conv2d_58 (Conv2D)           (None, 8, 8, 256)         590080
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 4, 4, 256)         0
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# conv2d_59 (Conv2D)           (None, 4, 4, 512)         1180160
# _________________________________________________________________
# conv2d_60 (Conv2D)           (None, 4, 4, 512)         2359808
# _________________________________________________________________
# conv2d_61 (Conv2D)           (None, 4, 4, 512)         2359808
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# conv2d_62 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# conv2d_63 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# conv2d_64 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 1, 1, 512)         0
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 1, 1, 512)         2048
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 14,987,850
# Trainable params: 14,985,162
# Non-trainable params: 2,688
# _________________________________________________________________

# %%
pretrained_model = create_functional_model()
model = keras.Sequential(pretrained_model)
pretrained_model.load_weights(weights_path)

# # baseline model
# extracted_layers = pretrained_model.layers[:-1]
# extracted_layers.append(keras.layers.Dense(100, name='dense_7', activation='softmax'))
# model = keras.Sequential(extracted_layers)

# # model A:
# extracted_layers = pretrained_model.layers[:-9]
# extracted_layers.append(keras.layers.Conv2D(filters=512, kernel_size=1, padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay)))
# extracted_layers.append(keras.layers.Conv2D(filters=512, kernel_size=1, padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay)))
# extracted_layers.append(keras.layers.Conv2D(filters=512, kernel_size=1, padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay)))
# extracted_layers.append(keras.layers.AveragePooling2D(pool_size=(2,2)))
# extracted_layers.append(keras.layers.BatchNormalization())
# extracted_layers.append(keras.layers.Flatten())
# extracted_layers.append(keras.layers.Dense(512, activation=tf.nn.relu))
# extracted_layers.append(keras.layers.Dropout(0.7))   
# extracted_layers.append(keras.layers.Dense(100, name='dense_7', activation='softmax'))
# model = keras.Sequential(extracted_layers)

# # model B
# extracted_layers = pretrained_model.layers[:-9]
# extracted_layers.append(keras.layers.Conv2D(filters=512, kernel_size=1, padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay)))
# extracted_layers.append(keras.layers.Conv2D(filters=512, kernel_size=1, padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay)))
# extracted_layers.append(keras.layers.Conv2D(filters=512, kernel_size=1, padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay)))
# extracted_layers.append(keras.layers.AveragePooling2D(pool_size=(2,2)))
# extracted_layers.append(keras.layers.BatchNormalization())
# extracted_layers.append(keras.layers.Flatten())
# extracted_layers.append(keras.layers.Dense(100, name='dense_7', activation='softmax'))
# model = keras.Sequential(extracted_layers)

# model C
def create_functional_model():
  model = keras.Sequential([    
  keras.layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu', input_shape=input_shape),
  keras.layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu'),
  keras.layers.AveragePooling2D(pool_size=(2,2)),  
  keras.layers.BatchNormalization(),  
  keras.layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay)),
  keras.layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay)),
  keras.layers.AveragePooling2D(pool_size=(2,2)),    
  keras.layers.Conv2D(filters=128, kernel_size=3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay)),
  keras.layers.Conv2D(filters=128, kernel_size=3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay)),
  keras.layers.Conv2D(filters=128, kernel_size=3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay)),
  keras.layers.AveragePooling2D(pool_size=(2,2)),
  keras.layers.BatchNormalization(),  
  keras.layers.Conv2D(filters=256, kernel_size=3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay)),
  keras.layers.Conv2D(filters=256, kernel_size=3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay)),
  keras.layers.Conv2D(filters=256, kernel_size=1, padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay)),
  keras.layers.AveragePooling2D(pool_size=(2,2)),
  keras.layers.BatchNormalization(),  
  keras.layers.Conv2D(filters=512, kernel_size=3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay)),
  keras.layers.Conv2D(filters=512, kernel_size=3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay)),
  keras.layers.Conv2D(filters=512, kernel_size=1, padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay)),
  keras.layers.AveragePooling2D(pool_size=(2,2)),
  keras.layers.BatchNormalization(),
  keras.layers.Flatten(),
  keras.layers.Dense(512, activation=tf.nn.relu),
  keras.layers.Dropout(0.7),   
  keras.layers.Dense(100, activation=tf.nn.softmax)
  ])
  return model
model = create_functional_model()

# baseline: 24, model A: 22, model B: 24, model C: 24
for layer in model.layers[:24]:
   layer.trainable = False
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_78 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_79 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# average_pooling2d_10 (Averag (None, 16, 16, 32)        0
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 16, 16, 32)        128
# _________________________________________________________________
# conv2d_80 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_81 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# average_pooling2d_11 (Averag (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_82 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# conv2d_83 (Conv2D)           (None, 8, 8, 128)         147584
# _________________________________________________________________
# conv2d_84 (Conv2D)           (None, 8, 8, 128)         147584
# _________________________________________________________________
# average_pooling2d_12 (Averag (None, 4, 4, 128)         0
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 4, 4, 128)         512
# _________________________________________________________________
# conv2d_85 (Conv2D)           (None, 4, 4, 256)         295168
# _________________________________________________________________
# conv2d_86 (Conv2D)           (None, 4, 4, 256)         590080
# _________________________________________________________________
# conv2d_87 (Conv2D)           (None, 4, 4, 256)         65792
# _________________________________________________________________
# average_pooling2d_13 (Averag (None, 2, 2, 256)         0
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 2, 2, 256)         1024
# _________________________________________________________________
# conv2d_88 (Conv2D)           (None, 2, 2, 512)         1180160
# _________________________________________________________________
# conv2d_89 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# conv2d_90 (Conv2D)           (None, 2, 2, 512)         262656
# _________________________________________________________________
# average_pooling2d_14 (Averag (None, 1, 1, 512)         0
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 1, 1, 512)         2048
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 100)               51300
# =================================================================
# Total params: 5,505,924
# Trainable params: 51,300
# Non-trainable params: 5,454,624
# _________________________________________________________________

# %%
# training with augmentation
x_train = joblib.load('drive/My Drive/NN_Assignment/x_train.pkl')
y_train = joblib.load('drive/My Drive/NN_Assignment/y_train.pkl')
x_test = joblib.load('drive/My Drive/NN_Assignment/x_test.pkl')
y_test = joblib.load('drive/My Drive/NN_Assignment/y_test.pkl')

seq = iaa.Sequential([
    iaa.Fliplr(0.5)
])

seq2 = iaa.Sequential([
    iaa.GaussianBlur(sigma=(0, 0.5))
])

images_aug = seq.augment_images(x_train)
new_x_train = np.append(x_train, images_aug, axis=0)
images_aug2 = seq2.augment_images(new_x_train)
new_x_train = np.append(images_aug2, new_x_train, axis=0)

new_y_train = np.append(y_train, y_train, axis=0)
new_y_train = np.append(new_y_train, new_y_train, axis=0)

new_x_train = new_x_train/255.0
x_test = x_test/255.0

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
trainmodel = model.fit(new_x_train, new_y_train, epochs=epochs, validation_data=(x_test, y_test), batch_size=64, shuffle=True)

loss, acc = model.evaluate(x_test, y_test)
print("Accuracy: {:5.2f}%".format(100*acc))
# Out:
# Epoch 1/50
# 125/125 [==============================] - 1s 10ms/step - loss: 4.7307 - accuracy: 0.0075 - val_loss: 4.7301 - val_accuracy: 0.0100
# Epoch 2/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7306 - accuracy: 0.0072 - val_loss: 4.7300 - val_accuracy: 0.0100
# Epoch 3/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7306 - accuracy: 0.0072 - val_loss: 4.7300 - val_accuracy: 0.0100
# Epoch 4/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7305 - accuracy: 0.0070 - val_loss: 4.7300 - val_accuracy: 0.0110
# Epoch 5/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7305 - accuracy: 0.0061 - val_loss: 4.7299 - val_accuracy: 0.0100
# Epoch 6/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7305 - accuracy: 0.0074 - val_loss: 4.7299 - val_accuracy: 0.0100
# Epoch 7/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7304 - accuracy: 0.0068 - val_loss: 4.7299 - val_accuracy: 0.0090
# Epoch 8/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7304 - accuracy: 0.0072 - val_loss: 4.7298 - val_accuracy: 0.0100
# Epoch 9/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7303 - accuracy: 0.0084 - val_loss: 4.7298 - val_accuracy: 0.0100
# Epoch 10/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7303 - accuracy: 0.0089 - val_loss: 4.7298 - val_accuracy: 0.0100
# Epoch 11/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7303 - accuracy: 0.0069 - val_loss: 4.7297 - val_accuracy: 0.0100
# Epoch 12/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7302 - accuracy: 0.0084 - val_loss: 4.7297 - val_accuracy: 0.0110
# Epoch 13/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7302 - accuracy: 0.0077 - val_loss: 4.7297 - val_accuracy: 0.0110
# Epoch 14/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7302 - accuracy: 0.0082 - val_loss: 4.7297 - val_accuracy: 0.0140
# Epoch 15/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7301 - accuracy: 0.0076 - val_loss: 4.7296 - val_accuracy: 0.0100
# Epoch 16/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7301 - accuracy: 0.0088 - val_loss: 4.7296 - val_accuracy: 0.0120
# Epoch 17/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7301 - accuracy: 0.0088 - val_loss: 4.7296 - val_accuracy: 0.0100
# Epoch 18/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7300 - accuracy: 0.0085 - val_loss: 4.7295 - val_accuracy: 0.0100
# Epoch 19/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7300 - accuracy: 0.0089 - val_loss: 4.7295 - val_accuracy: 0.0140
# Epoch 20/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7299 - accuracy: 0.0082 - val_loss: 4.7295 - val_accuracy: 0.0120
# Epoch 21/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7299 - accuracy: 0.0074 - val_loss: 4.7294 - val_accuracy: 0.0120
# Epoch 22/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7299 - accuracy: 0.0103 - val_loss: 4.7294 - val_accuracy: 0.0150
# Epoch 23/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7298 - accuracy: 0.0086 - val_loss: 4.7294 - val_accuracy: 0.0150
# Epoch 24/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7298 - accuracy: 0.0093 - val_loss: 4.7293 - val_accuracy: 0.0090
# Epoch 25/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7298 - accuracy: 0.0079 - val_loss: 4.7293 - val_accuracy: 0.0130
# Epoch 26/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7297 - accuracy: 0.0094 - val_loss: 4.7293 - val_accuracy: 0.0120
# Epoch 27/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7297 - accuracy: 0.0085 - val_loss: 4.7292 - val_accuracy: 0.0130
# Epoch 28/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7297 - accuracy: 0.0094 - val_loss: 4.7292 - val_accuracy: 0.0210
# Epoch 29/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7296 - accuracy: 0.0099 - val_loss: 4.7292 - val_accuracy: 0.0150
# Epoch 30/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7296 - accuracy: 0.0117 - val_loss: 4.7291 - val_accuracy: 0.0210
# Epoch 31/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7296 - accuracy: 0.0117 - val_loss: 4.7291 - val_accuracy: 0.0150
# Epoch 32/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7295 - accuracy: 0.0109 - val_loss: 4.7291 - val_accuracy: 0.0150
# Epoch 33/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7295 - accuracy: 0.0111 - val_loss: 4.7290 - val_accuracy: 0.0130
# Epoch 34/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7294 - accuracy: 0.0098 - val_loss: 4.7290 - val_accuracy: 0.0140
# Epoch 35/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7294 - accuracy: 0.0108 - val_loss: 4.7290 - val_accuracy: 0.0190
# Epoch 36/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7294 - accuracy: 0.0111 - val_loss: 4.7289 - val_accuracy: 0.0160
# Epoch 37/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7293 - accuracy: 0.0106 - val_loss: 4.7289 - val_accuracy: 0.0160
# Epoch 38/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7293 - accuracy: 0.0119 - val_loss: 4.7289 - val_accuracy: 0.0190
# Epoch 39/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7293 - accuracy: 0.0103 - val_loss: 4.7288 - val_accuracy: 0.0220
# Epoch 40/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7292 - accuracy: 0.0113 - val_loss: 4.7288 - val_accuracy: 0.0150
# Epoch 41/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7292 - accuracy: 0.0110 - val_loss: 4.7288 - val_accuracy: 0.0170
# Epoch 42/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7292 - accuracy: 0.0099 - val_loss: 4.7288 - val_accuracy: 0.0170
# Epoch 43/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7292 - accuracy: 0.0125 - val_loss: 4.7287 - val_accuracy: 0.0200
# Epoch 44/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7291 - accuracy: 0.0117 - val_loss: 4.7287 - val_accuracy: 0.0140
# Epoch 45/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7290 - accuracy: 0.0104 - val_loss: 4.7287 - val_accuracy: 0.0210
# Epoch 46/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7290 - accuracy: 0.0116 - val_loss: 4.7286 - val_accuracy: 0.0160
# Epoch 47/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7290 - accuracy: 0.0134 - val_loss: 4.7286 - val_accuracy: 0.0200
# Epoch 48/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7289 - accuracy: 0.0145 - val_loss: 4.7286 - val_accuracy: 0.0170
# Epoch 49/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7289 - accuracy: 0.0130 - val_loss: 4.7285 - val_accuracy: 0.0160
# Epoch 50/50
# 125/125 [==============================] - 1s 8ms/step - loss: 4.7289 - accuracy: 0.0114 - val_loss: 4.7285 - val_accuracy: 0.0200
# 32/32 [==============================] - 0s 6ms/step - loss: 4.7285 - accuracy: 0.0200
# Accuracy:  2.00%

# %%
#plot accuracy of model in a graph
history = trainmodel.history
history.keys()

acc = history['val_accuracy']
val_acc = history['val_accuracy']
loss = history['loss']
val_loss = history['val_loss']

epochs = range(1, len(acc) + 1)

# "bo" is for "blue dot"
plt.plot(epochs, loss, 'bo', label='Training loss')
# b is for "solid blue line"
plt.plot(epochs, val_loss, 'b', label='Testing loss')
# "bo" is for "blue dot"
plt.plot(epochs, acc, 'go', label='Training accuracy')
# b is for "solid blue line"
plt.plot(epochs, val_acc, 'g', label='Testing accuracy')
plt.title('Graph of training and testing loss/accuracy vs number of epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss/Accuracy')
plt.legend()

plt.show()
plt.savefig('evaluation.png')

# %%
model.save('model_c.h5')

# %%
# make predictions
import cv2
import numpy as np
from tqdm import tqdm
import os

correct = 0
wrong = 0

test_location = 'drive/My Drive/NN_Assignment/downsized/test'
test_list = []

for test_dir in os.listdir(test_location):
  test_list.append(test_dir)
test_list = sorted(test_list)

for data in test_list:
    path = os.path.join(test_location, data)
    class_num = test_list.index(data)
    
    # iterate over images by directories alphabetically
    for img in os.listdir(path):
      img_array = cv2.imread(os.path.join(path,img))  # convert to array
      images = np.expand_dims(img_array, axis = 0)
      predictions = model.predict(images)
      print("Actual Class:", class_num, test_list[class_num], 
            "\t Prediction:", np.argmax(predictions), test_list[np.argmax(predictions, axis=1)[0]])
      if(class_num == np.argmax(predictions)):
        correct +=1
      else:
        wrong +=1

print("Accuracy: {:5.2f}%".format(correct/(wrong + correct)*100))
# Out:
# Actual Class: 0 50_Cent 	 Prediction: 47 Madonna
# Actual Class: 0 50_Cent 	 Prediction: 47 Madonna
# Actual Class: 0 50_Cent 	 Prediction: 47 Madonna
# Actual Class: 0 50_Cent 	 Prediction: 47 Madonna
# Actual Class: 0 50_Cent 	 Prediction: 47 Madonna
# Actual Class: 0 50_Cent 	 Prediction: 47 Madonna
# Actual Class: 0 50_Cent 	 Prediction: 47 Madonna
# Actual Class: 0 50_Cent 	 Prediction: 47 Madonna
# Actual Class: 0 50_Cent 	 Prediction: 47 Madonna
# Actual Class: 0 50_Cent 	 Prediction: 47 Madonna
# Actual Class: 1 Abigail_Breslin 	 Prediction: 47 Madonna
# Actual Class: 1 Abigail_Breslin 	 Prediction: 47 Madonna
# Actual Class: 1 Abigail_Breslin 	 Prediction: 81 Rooney_Mara
# Actual Class: 1 Abigail_Breslin 	 Prediction: 47 Madonna
# Actual Class: 1 Abigail_Breslin 	 Prediction: 81 Rooney_Mara
# Actual Class: 1 Abigail_Breslin 	 Prediction: 47 Madonna
# Actual Class: 1 Abigail_Breslin 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 1 Abigail_Breslin 	 Prediction: 81 Rooney_Mara
# Actual Class: 1 Abigail_Breslin 	 Prediction: 47 Madonna
# Actual Class: 1 Abigail_Breslin 	 Prediction: 47 Madonna
# Actual Class: 2 Adam_Sandler 	 Prediction: 47 Madonna
# Actual Class: 2 Adam_Sandler 	 Prediction: 47 Madonna
# Actual Class: 2 Adam_Sandler 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 2 Adam_Sandler 	 Prediction: 47 Madonna
# Actual Class: 2 Adam_Sandler 	 Prediction: 47 Madonna
# Actual Class: 2 Adam_Sandler 	 Prediction: 47 Madonna
# Actual Class: 2 Adam_Sandler 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 2 Adam_Sandler 	 Prediction: 81 Rooney_Mara
# Actual Class: 2 Adam_Sandler 	 Prediction: 47 Madonna
# Actual Class: 2 Adam_Sandler 	 Prediction: 47 Madonna
# Actual Class: 3 Amber_Valletta 	 Prediction: 47 Madonna
# Actual Class: 3 Amber_Valletta 	 Prediction: 47 Madonna
# Actual Class: 3 Amber_Valletta 	 Prediction: 47 Madonna
# Actual Class: 3 Amber_Valletta 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 3 Amber_Valletta 	 Prediction: 81 Rooney_Mara
# Actual Class: 3 Amber_Valletta 	 Prediction: 47 Madonna
# Actual Class: 3 Amber_Valletta 	 Prediction: 47 Madonna
# Actual Class: 3 Amber_Valletta 	 Prediction: 81 Rooney_Mara
# Actual Class: 3 Amber_Valletta 	 Prediction: 47 Madonna
# Actual Class: 3 Amber_Valletta 	 Prediction: 47 Madonna
# Actual Class: 4 Andie_MacDowell 	 Prediction: 47 Madonna
# Actual Class: 4 Andie_MacDowell 	 Prediction: 47 Madonna
# Actual Class: 4 Andie_MacDowell 	 Prediction: 81 Rooney_Mara
# Actual Class: 4 Andie_MacDowell 	 Prediction: 47 Madonna
# Actual Class: 4 Andie_MacDowell 	 Prediction: 47 Madonna
# Actual Class: 4 Andie_MacDowell 	 Prediction: 81 Rooney_Mara
# Actual Class: 4 Andie_MacDowell 	 Prediction: 47 Madonna
# Actual Class: 4 Andie_MacDowell 	 Prediction: 47 Madonna
# Actual Class: 4 Andie_MacDowell 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 4 Andie_MacDowell 	 Prediction: 47 Madonna
# Actual Class: 5 Annie_Wersching 	 Prediction: 47 Madonna
# Actual Class: 5 Annie_Wersching 	 Prediction: 47 Madonna
# Actual Class: 5 Annie_Wersching 	 Prediction: 81 Rooney_Mara
# Actual Class: 5 Annie_Wersching 	 Prediction: 47 Madonna
# Actual Class: 5 Annie_Wersching 	 Prediction: 47 Madonna
# Actual Class: 5 Annie_Wersching 	 Prediction: 47 Madonna
# Actual Class: 5 Annie_Wersching 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 5 Annie_Wersching 	 Prediction: 47 Madonna
# Actual Class: 5 Annie_Wersching 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 5 Annie_Wersching 	 Prediction: 47 Madonna
# Actual Class: 6 Audrina_Patridge 	 Prediction: 47 Madonna
# Actual Class: 6 Audrina_Patridge 	 Prediction: 47 Madonna
# Actual Class: 6 Audrina_Patridge 	 Prediction: 47 Madonna
# Actual Class: 6 Audrina_Patridge 	 Prediction: 47 Madonna
# Actual Class: 6 Audrina_Patridge 	 Prediction: 47 Madonna
# Actual Class: 6 Audrina_Patridge 	 Prediction: 81 Rooney_Mara
# Actual Class: 6 Audrina_Patridge 	 Prediction: 47 Madonna
# Actual Class: 6 Audrina_Patridge 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 6 Audrina_Patridge 	 Prediction: 47 Madonna
# Actual Class: 6 Audrina_Patridge 	 Prediction: 47 Madonna
# Actual Class: 7 Billy_Bob_Thornton 	 Prediction: 81 Rooney_Mara
# Actual Class: 7 Billy_Bob_Thornton 	 Prediction: 81 Rooney_Mara
# Actual Class: 7 Billy_Bob_Thornton 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 7 Billy_Bob_Thornton 	 Prediction: 81 Rooney_Mara
# Actual Class: 7 Billy_Bob_Thornton 	 Prediction: 81 Rooney_Mara
# Actual Class: 7 Billy_Bob_Thornton 	 Prediction: 47 Madonna
# Actual Class: 7 Billy_Bob_Thornton 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 7 Billy_Bob_Thornton 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 7 Billy_Bob_Thornton 	 Prediction: 47 Madonna
# Actual Class: 7 Billy_Bob_Thornton 	 Prediction: 47 Madonna
# Actual Class: 8 Brad_Pitt 	 Prediction: 81 Rooney_Mara
# Actual Class: 8 Brad_Pitt 	 Prediction: 81 Rooney_Mara
# Actual Class: 8 Brad_Pitt 	 Prediction: 47 Madonna
# Actual Class: 8 Brad_Pitt 	 Prediction: 47 Madonna
# Actual Class: 8 Brad_Pitt 	 Prediction: 47 Madonna
# Actual Class: 8 Brad_Pitt 	 Prediction: 47 Madonna
# Actual Class: 8 Brad_Pitt 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 8 Brad_Pitt 	 Prediction: 81 Rooney_Mara
# Actual Class: 8 Brad_Pitt 	 Prediction: 47 Madonna
# Actual Class: 8 Brad_Pitt 	 Prediction: 47 Madonna
# Actual Class: 9 Brandon_Routh 	 Prediction: 47 Madonna
# Actual Class: 9 Brandon_Routh 	 Prediction: 47 Madonna
# Actual Class: 9 Brandon_Routh 	 Prediction: 81 Rooney_Mara
# Actual Class: 9 Brandon_Routh 	 Prediction: 81 Rooney_Mara
# Actual Class: 9 Brandon_Routh 	 Prediction: 47 Madonna
# Actual Class: 9 Brandon_Routh 	 Prediction: 47 Madonna
# Actual Class: 9 Brandon_Routh 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 9 Brandon_Routh 	 Prediction: 47 Madonna
# Actual Class: 9 Brandon_Routh 	 Prediction: 47 Madonna
# Actual Class: 9 Brandon_Routh 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 10 Bridget_Moynahan 	 Prediction: 47 Madonna
# Actual Class: 10 Bridget_Moynahan 	 Prediction: 47 Madonna
# Actual Class: 10 Bridget_Moynahan 	 Prediction: 47 Madonna
# Actual Class: 10 Bridget_Moynahan 	 Prediction: 47 Madonna
# Actual Class: 10 Bridget_Moynahan 	 Prediction: 47 Madonna
# Actual Class: 10 Bridget_Moynahan 	 Prediction: 81 Rooney_Mara
# Actual Class: 10 Bridget_Moynahan 	 Prediction: 81 Rooney_Mara
# Actual Class: 10 Bridget_Moynahan 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 10 Bridget_Moynahan 	 Prediction: 47 Madonna
# Actual Class: 10 Bridget_Moynahan 	 Prediction: 47 Madonna
# Actual Class: 11 Callie_Thorne 	 Prediction: 47 Madonna
# Actual Class: 11 Callie_Thorne 	 Prediction: 47 Madonna
# Actual Class: 11 Callie_Thorne 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 11 Callie_Thorne 	 Prediction: 47 Madonna
# Actual Class: 11 Callie_Thorne 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 11 Callie_Thorne 	 Prediction: 47 Madonna
# Actual Class: 11 Callie_Thorne 	 Prediction: 47 Madonna
# Actual Class: 11 Callie_Thorne 	 Prediction: 47 Madonna
# Actual Class: 11 Callie_Thorne 	 Prediction: 47 Madonna
# Actual Class: 11 Callie_Thorne 	 Prediction: 47 Madonna
# Actual Class: 12 Casey_Affleck 	 Prediction: 81 Rooney_Mara
# Actual Class: 12 Casey_Affleck 	 Prediction: 47 Madonna
# Actual Class: 12 Casey_Affleck 	 Prediction: 47 Madonna
# Actual Class: 12 Casey_Affleck 	 Prediction: 81 Rooney_Mara
# Actual Class: 12 Casey_Affleck 	 Prediction: 47 Madonna
# Actual Class: 12 Casey_Affleck 	 Prediction: 47 Madonna
# Actual Class: 12 Casey_Affleck 	 Prediction: 47 Madonna
# Actual Class: 12 Casey_Affleck 	 Prediction: 81 Rooney_Mara
# Actual Class: 12 Casey_Affleck 	 Prediction: 47 Madonna
# Actual Class: 12 Casey_Affleck 	 Prediction: 47 Madonna
# Actual Class: 13 Colin_Firth 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 13 Colin_Firth 	 Prediction: 47 Madonna
# Actual Class: 13 Colin_Firth 	 Prediction: 47 Madonna
# Actual Class: 13 Colin_Firth 	 Prediction: 47 Madonna
# Actual Class: 13 Colin_Firth 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 13 Colin_Firth 	 Prediction: 81 Rooney_Mara
# Actual Class: 13 Colin_Firth 	 Prediction: 47 Madonna
# Actual Class: 13 Colin_Firth 	 Prediction: 47 Madonna
# Actual Class: 13 Colin_Firth 	 Prediction: 47 Madonna
# Actual Class: 13 Colin_Firth 	 Prediction: 47 Madonna
# Actual Class: 14 Cuba_Gooding_Jr 	 Prediction: 47 Madonna
# Actual Class: 14 Cuba_Gooding_Jr 	 Prediction: 81 Rooney_Mara
# Actual Class: 14 Cuba_Gooding_Jr 	 Prediction: 47 Madonna
# Actual Class: 14 Cuba_Gooding_Jr 	 Prediction: 47 Madonna
# Actual Class: 14 Cuba_Gooding_Jr 	 Prediction: 47 Madonna
# Actual Class: 14 Cuba_Gooding_Jr 	 Prediction: 47 Madonna
# Actual Class: 14 Cuba_Gooding_Jr 	 Prediction: 47 Madonna
# Actual Class: 14 Cuba_Gooding_Jr 	 Prediction: 81 Rooney_Mara
# Actual Class: 14 Cuba_Gooding_Jr 	 Prediction: 81 Rooney_Mara
# Actual Class: 14 Cuba_Gooding_Jr 	 Prediction: 47 Madonna
# Actual Class: 15 Danny_DeVito 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 15 Danny_DeVito 	 Prediction: 47 Madonna
# Actual Class: 15 Danny_DeVito 	 Prediction: 47 Madonna
# Actual Class: 15 Danny_DeVito 	 Prediction: 47 Madonna
# Actual Class: 15 Danny_DeVito 	 Prediction: 81 Rooney_Mara
# Actual Class: 15 Danny_DeVito 	 Prediction: 47 Madonna
# Actual Class: 15 Danny_DeVito 	 Prediction: 47 Madonna
# Actual Class: 15 Danny_DeVito 	 Prediction: 81 Rooney_Mara
# Actual Class: 15 Danny_DeVito 	 Prediction: 81 Rooney_Mara
# Actual Class: 15 Danny_DeVito 	 Prediction: 47 Madonna
# Actual Class: 16 David_Tennant 	 Prediction: 81 Rooney_Mara
# Actual Class: 16 David_Tennant 	 Prediction: 81 Rooney_Mara
# Actual Class: 16 David_Tennant 	 Prediction: 47 Madonna
# Actual Class: 16 David_Tennant 	 Prediction: 47 Madonna
# Actual Class: 16 David_Tennant 	 Prediction: 81 Rooney_Mara
# Actual Class: 16 David_Tennant 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 16 David_Tennant 	 Prediction: 47 Madonna
# Actual Class: 16 David_Tennant 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 16 David_Tennant 	 Prediction: 47 Madonna
# Actual Class: 16 David_Tennant 	 Prediction: 81 Rooney_Mara
# Actual Class: 17 Dermot_Mulroney 	 Prediction: 81 Rooney_Mara
# Actual Class: 17 Dermot_Mulroney 	 Prediction: 47 Madonna
# Actual Class: 17 Dermot_Mulroney 	 Prediction: 47 Madonna
# Actual Class: 17 Dermot_Mulroney 	 Prediction: 47 Madonna
# Actual Class: 17 Dermot_Mulroney 	 Prediction: 47 Madonna
# Actual Class: 17 Dermot_Mulroney 	 Prediction: 47 Madonna
# Actual Class: 17 Dermot_Mulroney 	 Prediction: 47 Madonna
# Actual Class: 17 Dermot_Mulroney 	 Prediction: 81 Rooney_Mara
# Actual Class: 17 Dermot_Mulroney 	 Prediction: 47 Madonna
# Actual Class: 17 Dermot_Mulroney 	 Prediction: 81 Rooney_Mara
# Actual Class: 18 Diane_Lane 	 Prediction: 47 Madonna
# Actual Class: 18 Diane_Lane 	 Prediction: 47 Madonna
# Actual Class: 18 Diane_Lane 	 Prediction: 47 Madonna
# Actual Class: 18 Diane_Lane 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 18 Diane_Lane 	 Prediction: 47 Madonna
# Actual Class: 18 Diane_Lane 	 Prediction: 81 Rooney_Mara
# Actual Class: 18 Diane_Lane 	 Prediction: 81 Rooney_Mara
# Actual Class: 18 Diane_Lane 	 Prediction: 47 Madonna
# Actual Class: 18 Diane_Lane 	 Prediction: 47 Madonna
# Actual Class: 18 Diane_Lane 	 Prediction: 47 Madonna
# Actual Class: 19 Dianna_Agron 	 Prediction: 47 Madonna
# Actual Class: 19 Dianna_Agron 	 Prediction: 81 Rooney_Mara
# Actual Class: 19 Dianna_Agron 	 Prediction: 81 Rooney_Mara
# Actual Class: 19 Dianna_Agron 	 Prediction: 81 Rooney_Mara
# Actual Class: 19 Dianna_Agron 	 Prediction: 47 Madonna
# Actual Class: 19 Dianna_Agron 	 Prediction: 47 Madonna
# Actual Class: 19 Dianna_Agron 	 Prediction: 47 Madonna
# Actual Class: 19 Dianna_Agron 	 Prediction: 81 Rooney_Mara
# Actual Class: 19 Dianna_Agron 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 19 Dianna_Agron 	 Prediction: 81 Rooney_Mara
# Actual Class: 20 Eddie_McClintock 	 Prediction: 81 Rooney_Mara
# Actual Class: 20 Eddie_McClintock 	 Prediction: 47 Madonna
# Actual Class: 20 Eddie_McClintock 	 Prediction: 47 Madonna
# Actual Class: 20 Eddie_McClintock 	 Prediction: 47 Madonna
# Actual Class: 20 Eddie_McClintock 	 Prediction: 47 Madonna
# Actual Class: 20 Eddie_McClintock 	 Prediction: 47 Madonna
# Actual Class: 20 Eddie_McClintock 	 Prediction: 47 Madonna
# Actual Class: 20 Eddie_McClintock 	 Prediction: 47 Madonna
# Actual Class: 20 Eddie_McClintock 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 20 Eddie_McClintock 	 Prediction: 47 Madonna
# Actual Class: 21 Elijah_Wood 	 Prediction: 47 Madonna
# Actual Class: 21 Elijah_Wood 	 Prediction: 47 Madonna
# Actual Class: 21 Elijah_Wood 	 Prediction: 47 Madonna
# Actual Class: 21 Elijah_Wood 	 Prediction: 81 Rooney_Mara
# Actual Class: 21 Elijah_Wood 	 Prediction: 47 Madonna
# Actual Class: 21 Elijah_Wood 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 21 Elijah_Wood 	 Prediction: 47 Madonna
# Actual Class: 21 Elijah_Wood 	 Prediction: 81 Rooney_Mara
# Actual Class: 21 Elijah_Wood 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 21 Elijah_Wood 	 Prediction: 47 Madonna
# Actual Class: 22 Elizabeth_Berkley 	 Prediction: 81 Rooney_Mara
# Actual Class: 22 Elizabeth_Berkley 	 Prediction: 47 Madonna
# Actual Class: 22 Elizabeth_Berkley 	 Prediction: 47 Madonna
# Actual Class: 22 Elizabeth_Berkley 	 Prediction: 47 Madonna
# Actual Class: 22 Elizabeth_Berkley 	 Prediction: 81 Rooney_Mara
# Actual Class: 22 Elizabeth_Berkley 	 Prediction: 81 Rooney_Mara
# Actual Class: 22 Elizabeth_Berkley 	 Prediction: 47 Madonna
# Actual Class: 22 Elizabeth_Berkley 	 Prediction: 47 Madonna
# Actual Class: 22 Elizabeth_Berkley 	 Prediction: 47 Madonna
# Actual Class: 22 Elizabeth_Berkley 	 Prediction: 47 Madonna
# Actual Class: 23 Emma_Roberts 	 Prediction: 47 Madonna
# Actual Class: 23 Emma_Roberts 	 Prediction: 47 Madonna
# Actual Class: 23 Emma_Roberts 	 Prediction: 47 Madonna
# Actual Class: 23 Emma_Roberts 	 Prediction: 47 Madonna
# Actual Class: 23 Emma_Roberts 	 Prediction: 81 Rooney_Mara
# Actual Class: 23 Emma_Roberts 	 Prediction: 81 Rooney_Mara
# Actual Class: 23 Emma_Roberts 	 Prediction: 47 Madonna
# Actual Class: 23 Emma_Roberts 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 23 Emma_Roberts 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 23 Emma_Roberts 	 Prediction: 81 Rooney_Mara
# Actual Class: 24 Emma_Stone 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 24 Emma_Stone 	 Prediction: 47 Madonna
# Actual Class: 24 Emma_Stone 	 Prediction: 47 Madonna
# Actual Class: 24 Emma_Stone 	 Prediction: 47 Madonna
# Actual Class: 24 Emma_Stone 	 Prediction: 81 Rooney_Mara
# Actual Class: 24 Emma_Stone 	 Prediction: 81 Rooney_Mara
# Actual Class: 24 Emma_Stone 	 Prediction: 47 Madonna
# Actual Class: 24 Emma_Stone 	 Prediction: 47 Madonna
# Actual Class: 24 Emma_Stone 	 Prediction: 47 Madonna
# Actual Class: 24 Emma_Stone 	 Prediction: 47 Madonna
# Actual Class: 25 Fergie 	 Prediction: 47 Madonna
# Actual Class: 25 Fergie 	 Prediction: 47 Madonna
# Actual Class: 25 Fergie 	 Prediction: 47 Madonna
# Actual Class: 25 Fergie 	 Prediction: 47 Madonna
# Actual Class: 25 Fergie 	 Prediction: 47 Madonna
# Actual Class: 25 Fergie 	 Prediction: 47 Madonna
# Actual Class: 25 Fergie 	 Prediction: 47 Madonna
# Actual Class: 25 Fergie 	 Prediction: 81 Rooney_Mara
# Actual Class: 25 Fergie 	 Prediction: 81 Rooney_Mara
# Actual Class: 25 Fergie 	 Prediction: 81 Rooney_Mara
# Actual Class: 26 George_Clooney 	 Prediction: 47 Madonna
# Actual Class: 26 George_Clooney 	 Prediction: 81 Rooney_Mara
# Actual Class: 26 George_Clooney 	 Prediction: 47 Madonna
# Actual Class: 26 George_Clooney 	 Prediction: 47 Madonna
# Actual Class: 26 George_Clooney 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 26 George_Clooney 	 Prediction: 47 Madonna
# Actual Class: 26 George_Clooney 	 Prediction: 47 Madonna
# Actual Class: 26 George_Clooney 	 Prediction: 47 Madonna
# Actual Class: 26 George_Clooney 	 Prediction: 47 Madonna
# Actual Class: 26 George_Clooney 	 Prediction: 81 Rooney_Mara
# Actual Class: 27 Gwyneth_Paltrow 	 Prediction: 81 Rooney_Mara
# Actual Class: 27 Gwyneth_Paltrow 	 Prediction: 47 Madonna
# Actual Class: 27 Gwyneth_Paltrow 	 Prediction: 47 Madonna
# Actual Class: 27 Gwyneth_Paltrow 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 27 Gwyneth_Paltrow 	 Prediction: 47 Madonna
# Actual Class: 27 Gwyneth_Paltrow 	 Prediction: 81 Rooney_Mara
# Actual Class: 27 Gwyneth_Paltrow 	 Prediction: 47 Madonna
# Actual Class: 27 Gwyneth_Paltrow 	 Prediction: 47 Madonna
# Actual Class: 27 Gwyneth_Paltrow 	 Prediction: 81 Rooney_Mara
# Actual Class: 27 Gwyneth_Paltrow 	 Prediction: 47 Madonna
# Actual Class: 28 Holliday_Grainger 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 28 Holliday_Grainger 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 28 Holliday_Grainger 	 Prediction: 47 Madonna
# Actual Class: 28 Holliday_Grainger 	 Prediction: 81 Rooney_Mara
# Actual Class: 28 Holliday_Grainger 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 28 Holliday_Grainger 	 Prediction: 81 Rooney_Mara
# Actual Class: 28 Holliday_Grainger 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 28 Holliday_Grainger 	 Prediction: 47 Madonna
# Actual Class: 28 Holliday_Grainger 	 Prediction: 47 Madonna
# Actual Class: 28 Holliday_Grainger 	 Prediction: 81 Rooney_Mara
# Actual Class: 29 Ice_Cube 	 Prediction: 47 Madonna
# Actual Class: 29 Ice_Cube 	 Prediction: 81 Rooney_Mara
# Actual Class: 29 Ice_Cube 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 29 Ice_Cube 	 Prediction: 47 Madonna
# Actual Class: 29 Ice_Cube 	 Prediction: 47 Madonna
# Actual Class: 29 Ice_Cube 	 Prediction: 47 Madonna
# Actual Class: 29 Ice_Cube 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 29 Ice_Cube 	 Prediction: 47 Madonna
# Actual Class: 29 Ice_Cube 	 Prediction: 47 Madonna
# Actual Class: 29 Ice_Cube 	 Prediction: 47 Madonna
# Actual Class: 30 Jackie_Chan 	 Prediction: 81 Rooney_Mara
# Actual Class: 30 Jackie_Chan 	 Prediction: 47 Madonna
# Actual Class: 30 Jackie_Chan 	 Prediction: 47 Madonna
# Actual Class: 30 Jackie_Chan 	 Prediction: 81 Rooney_Mara
# Actual Class: 30 Jackie_Chan 	 Prediction: 47 Madonna
# Actual Class: 30 Jackie_Chan 	 Prediction: 47 Madonna
# Actual Class: 30 Jackie_Chan 	 Prediction: 47 Madonna
# Actual Class: 30 Jackie_Chan 	 Prediction: 47 Madonna
# Actual Class: 30 Jackie_Chan 	 Prediction: 81 Rooney_Mara
# Actual Class: 30 Jackie_Chan 	 Prediction: 81 Rooney_Mara
# Actual Class: 31 James_Woods 	 Prediction: 47 Madonna
# Actual Class: 31 James_Woods 	 Prediction: 47 Madonna
# Actual Class: 31 James_Woods 	 Prediction: 47 Madonna
# Actual Class: 31 James_Woods 	 Prediction: 47 Madonna
# Actual Class: 31 James_Woods 	 Prediction: 81 Rooney_Mara
# Actual Class: 31 James_Woods 	 Prediction: 81 Rooney_Mara
# Actual Class: 31 James_Woods 	 Prediction: 81 Rooney_Mara
# Actual Class: 31 James_Woods 	 Prediction: 47 Madonna
# Actual Class: 31 James_Woods 	 Prediction: 81 Rooney_Mara
# Actual Class: 31 James_Woods 	 Prediction: 47 Madonna
# Actual Class: 32 Jamie_Lee_Curtis 	 Prediction: 81 Rooney_Mara
# Actual Class: 32 Jamie_Lee_Curtis 	 Prediction: 47 Madonna
# Actual Class: 32 Jamie_Lee_Curtis 	 Prediction: 81 Rooney_Mara
# Actual Class: 32 Jamie_Lee_Curtis 	 Prediction: 47 Madonna
# Actual Class: 32 Jamie_Lee_Curtis 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 32 Jamie_Lee_Curtis 	 Prediction: 47 Madonna
# Actual Class: 32 Jamie_Lee_Curtis 	 Prediction: 47 Madonna
# Actual Class: 32 Jamie_Lee_Curtis 	 Prediction: 47 Madonna
# Actual Class: 32 Jamie_Lee_Curtis 	 Prediction: 47 Madonna
# Actual Class: 32 Jamie_Lee_Curtis 	 Prediction: 81 Rooney_Mara
# Actual Class: 33 Jeffrey_Tambor 	 Prediction: 81 Rooney_Mara
# Actual Class: 33 Jeffrey_Tambor 	 Prediction: 47 Madonna
# Actual Class: 33 Jeffrey_Tambor 	 Prediction: 47 Madonna
# Actual Class: 33 Jeffrey_Tambor 	 Prediction: 47 Madonna
# Actual Class: 33 Jeffrey_Tambor 	 Prediction: 81 Rooney_Mara
# Actual Class: 33 Jeffrey_Tambor 	 Prediction: 47 Madonna
# Actual Class: 33 Jeffrey_Tambor 	 Prediction: 47 Madonna
# Actual Class: 33 Jeffrey_Tambor 	 Prediction: 81 Rooney_Mara
# Actual Class: 33 Jeffrey_Tambor 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 33 Jeffrey_Tambor 	 Prediction: 47 Madonna
# Actual Class: 34 Jessica_Lange 	 Prediction: 47 Madonna
# Actual Class: 34 Jessica_Lange 	 Prediction: 47 Madonna
# Actual Class: 34 Jessica_Lange 	 Prediction: 81 Rooney_Mara
# Actual Class: 34 Jessica_Lange 	 Prediction: 47 Madonna
# Actual Class: 34 Jessica_Lange 	 Prediction: 47 Madonna
# Actual Class: 34 Jessica_Lange 	 Prediction: 47 Madonna
# Actual Class: 34 Jessica_Lange 	 Prediction: 47 Madonna
# Actual Class: 34 Jessica_Lange 	 Prediction: 47 Madonna
# Actual Class: 34 Jessica_Lange 	 Prediction: 47 Madonna
# Actual Class: 34 Jessica_Lange 	 Prediction: 47 Madonna
# Actual Class: 35 John_Leguizamo 	 Prediction: 47 Madonna
# Actual Class: 35 John_Leguizamo 	 Prediction: 81 Rooney_Mara
# Actual Class: 35 John_Leguizamo 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 35 John_Leguizamo 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 35 John_Leguizamo 	 Prediction: 47 Madonna
# Actual Class: 35 John_Leguizamo 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 35 John_Leguizamo 	 Prediction: 81 Rooney_Mara
# Actual Class: 35 John_Leguizamo 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 35 John_Leguizamo 	 Prediction: 81 Rooney_Mara
# Actual Class: 35 John_Leguizamo 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 36 Jonny_Lee_Miller 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 36 Jonny_Lee_Miller 	 Prediction: 81 Rooney_Mara
# Actual Class: 36 Jonny_Lee_Miller 	 Prediction: 47 Madonna
# Actual Class: 36 Jonny_Lee_Miller 	 Prediction: 81 Rooney_Mara
# Actual Class: 36 Jonny_Lee_Miller 	 Prediction: 47 Madonna
# Actual Class: 36 Jonny_Lee_Miller 	 Prediction: 47 Madonna
# Actual Class: 36 Jonny_Lee_Miller 	 Prediction: 47 Madonna
# Actual Class: 36 Jonny_Lee_Miller 	 Prediction: 81 Rooney_Mara
# Actual Class: 36 Jonny_Lee_Miller 	 Prediction: 47 Madonna
# Actual Class: 36 Jonny_Lee_Miller 	 Prediction: 47 Madonna
# Actual Class: 37 Josh_Brolin 	 Prediction: 47 Madonna
# Actual Class: 37 Josh_Brolin 	 Prediction: 47 Madonna
# Actual Class: 37 Josh_Brolin 	 Prediction: 47 Madonna
# Actual Class: 37 Josh_Brolin 	 Prediction: 47 Madonna
# Actual Class: 37 Josh_Brolin 	 Prediction: 47 Madonna
# Actual Class: 37 Josh_Brolin 	 Prediction: 47 Madonna
# Actual Class: 37 Josh_Brolin 	 Prediction: 81 Rooney_Mara
# Actual Class: 37 Josh_Brolin 	 Prediction: 81 Rooney_Mara
# Actual Class: 37 Josh_Brolin 	 Prediction: 47 Madonna
# Actual Class: 37 Josh_Brolin 	 Prediction: 81 Rooney_Mara
# Actual Class: 38 Juliette_Lewis 	 Prediction: 47 Madonna
# Actual Class: 38 Juliette_Lewis 	 Prediction: 47 Madonna
# Actual Class: 38 Juliette_Lewis 	 Prediction: 81 Rooney_Mara
# Actual Class: 38 Juliette_Lewis 	 Prediction: 81 Rooney_Mara
# Actual Class: 38 Juliette_Lewis 	 Prediction: 81 Rooney_Mara
# Actual Class: 38 Juliette_Lewis 	 Prediction: 47 Madonna
# Actual Class: 38 Juliette_Lewis 	 Prediction: 81 Rooney_Mara
# Actual Class: 38 Juliette_Lewis 	 Prediction: 47 Madonna
# Actual Class: 38 Juliette_Lewis 	 Prediction: 81 Rooney_Mara
# Actual Class: 38 Juliette_Lewis 	 Prediction: 47 Madonna
# Actual Class: 39 Katherine_Heigl 	 Prediction: 47 Madonna
# Actual Class: 39 Katherine_Heigl 	 Prediction: 47 Madonna
# Actual Class: 39 Katherine_Heigl 	 Prediction: 47 Madonna
# Actual Class: 39 Katherine_Heigl 	 Prediction: 47 Madonna
# Actual Class: 39 Katherine_Heigl 	 Prediction: 47 Madonna
# Actual Class: 39 Katherine_Heigl 	 Prediction: 47 Madonna
# Actual Class: 39 Katherine_Heigl 	 Prediction: 47 Madonna
# Actual Class: 39 Katherine_Heigl 	 Prediction: 47 Madonna
# Actual Class: 39 Katherine_Heigl 	 Prediction: 81 Rooney_Mara
# Actual Class: 39 Katherine_Heigl 	 Prediction: 47 Madonna
# Actual Class: 40 Kathy_Bates 	 Prediction: 47 Madonna
# Actual Class: 40 Kathy_Bates 	 Prediction: 47 Madonna
# Actual Class: 40 Kathy_Bates 	 Prediction: 47 Madonna
# Actual Class: 40 Kathy_Bates 	 Prediction: 47 Madonna
# Actual Class: 40 Kathy_Bates 	 Prediction: 47 Madonna
# Actual Class: 40 Kathy_Bates 	 Prediction: 47 Madonna
# Actual Class: 40 Kathy_Bates 	 Prediction: 47 Madonna
# Actual Class: 40 Kathy_Bates 	 Prediction: 47 Madonna
# Actual Class: 40 Kathy_Bates 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 40 Kathy_Bates 	 Prediction: 47 Madonna
# Actual Class: 41 Kenneth_Branagh 	 Prediction: 81 Rooney_Mara
# Actual Class: 41 Kenneth_Branagh 	 Prediction: 47 Madonna
# Actual Class: 41 Kenneth_Branagh 	 Prediction: 81 Rooney_Mara
# Actual Class: 41 Kenneth_Branagh 	 Prediction: 47 Madonna
# Actual Class: 41 Kenneth_Branagh 	 Prediction: 47 Madonna
# Actual Class: 41 Kenneth_Branagh 	 Prediction: 47 Madonna
# Actual Class: 41 Kenneth_Branagh 	 Prediction: 47 Madonna
# Actual Class: 41 Kenneth_Branagh 	 Prediction: 47 Madonna
# Actual Class: 41 Kenneth_Branagh 	 Prediction: 47 Madonna
# Actual Class: 41 Kenneth_Branagh 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 42 Kirsten_Dunst 	 Prediction: 81 Rooney_Mara
# Actual Class: 42 Kirsten_Dunst 	 Prediction: 47 Madonna
# Actual Class: 42 Kirsten_Dunst 	 Prediction: 81 Rooney_Mara
# Actual Class: 42 Kirsten_Dunst 	 Prediction: 47 Madonna
# Actual Class: 42 Kirsten_Dunst 	 Prediction: 47 Madonna
# Actual Class: 42 Kirsten_Dunst 	 Prediction: 47 Madonna
# Actual Class: 42 Kirsten_Dunst 	 Prediction: 47 Madonna
# Actual Class: 42 Kirsten_Dunst 	 Prediction: 81 Rooney_Mara
# Actual Class: 42 Kirsten_Dunst 	 Prediction: 47 Madonna
# Actual Class: 42 Kirsten_Dunst 	 Prediction: 47 Madonna
# Actual Class: 43 Laurence_Fishburne 	 Prediction: 47 Madonna
# Actual Class: 43 Laurence_Fishburne 	 Prediction: 47 Madonna
# Actual Class: 43 Laurence_Fishburne 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 43 Laurence_Fishburne 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 43 Laurence_Fishburne 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 43 Laurence_Fishburne 	 Prediction: 47 Madonna
# Actual Class: 43 Laurence_Fishburne 	 Prediction: 47 Madonna
# Actual Class: 43 Laurence_Fishburne 	 Prediction: 47 Madonna
# Actual Class: 43 Laurence_Fishburne 	 Prediction: 47 Madonna
# Actual Class: 43 Laurence_Fishburne 	 Prediction: 47 Madonna
# Actual Class: 44 Lou_Diamond_Phillips 	 Prediction: 47 Madonna
# Actual Class: 44 Lou_Diamond_Phillips 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 44 Lou_Diamond_Phillips 	 Prediction: 47 Madonna
# Actual Class: 44 Lou_Diamond_Phillips 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 44 Lou_Diamond_Phillips 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 44 Lou_Diamond_Phillips 	 Prediction: 81 Rooney_Mara
# Actual Class: 44 Lou_Diamond_Phillips 	 Prediction: 47 Madonna
# Actual Class: 44 Lou_Diamond_Phillips 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 44 Lou_Diamond_Phillips 	 Prediction: 47 Madonna
# Actual Class: 44 Lou_Diamond_Phillips 	 Prediction: 47 Madonna
# Actual Class: 45 Louis_CK 	 Prediction: 47 Madonna
# Actual Class: 45 Louis_CK 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 45 Louis_CK 	 Prediction: 81 Rooney_Mara
# Actual Class: 45 Louis_CK 	 Prediction: 47 Madonna
# Actual Class: 45 Louis_CK 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 45 Louis_CK 	 Prediction: 47 Madonna
# Actual Class: 45 Louis_CK 	 Prediction: 47 Madonna
# Actual Class: 45 Louis_CK 	 Prediction: 47 Madonna
# Actual Class: 45 Louis_CK 	 Prediction: 47 Madonna
# Actual Class: 45 Louis_CK 	 Prediction: 47 Madonna
# Actual Class: 46 Lukas_Haas 	 Prediction: 47 Madonna
# Actual Class: 46 Lukas_Haas 	 Prediction: 47 Madonna
# Actual Class: 46 Lukas_Haas 	 Prediction: 81 Rooney_Mara
# Actual Class: 46 Lukas_Haas 	 Prediction: 47 Madonna
# Actual Class: 46 Lukas_Haas 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 46 Lukas_Haas 	 Prediction: 47 Madonna
# Actual Class: 46 Lukas_Haas 	 Prediction: 47 Madonna
# Actual Class: 46 Lukas_Haas 	 Prediction: 47 Madonna
# Actual Class: 46 Lukas_Haas 	 Prediction: 47 Madonna
# Actual Class: 46 Lukas_Haas 	 Prediction: 81 Rooney_Mara
# Actual Class: 47 Madonna 	 Prediction: 47 Madonna
# Actual Class: 47 Madonna 	 Prediction: 47 Madonna
# Actual Class: 47 Madonna 	 Prediction: 47 Madonna
# Actual Class: 47 Madonna 	 Prediction: 47 Madonna
# Actual Class: 47 Madonna 	 Prediction: 47 Madonna
# Actual Class: 47 Madonna 	 Prediction: 47 Madonna
# Actual Class: 47 Madonna 	 Prediction: 47 Madonna
# Actual Class: 47 Madonna 	 Prediction: 47 Madonna
# Actual Class: 47 Madonna 	 Prediction: 81 Rooney_Mara
# Actual Class: 47 Madonna 	 Prediction: 47 Madonna
# Actual Class: 48 Marg_Helgenberger 	 Prediction: 47 Madonna
# Actual Class: 48 Marg_Helgenberger 	 Prediction: 47 Madonna
# Actual Class: 48 Marg_Helgenberger 	 Prediction: 47 Madonna
# Actual Class: 48 Marg_Helgenberger 	 Prediction: 47 Madonna
# Actual Class: 48 Marg_Helgenberger 	 Prediction: 47 Madonna
# Actual Class: 48 Marg_Helgenberger 	 Prediction: 47 Madonna
# Actual Class: 48 Marg_Helgenberger 	 Prediction: 47 Madonna
# Actual Class: 48 Marg_Helgenberger 	 Prediction: 47 Madonna
# Actual Class: 48 Marg_Helgenberger 	 Prediction: 47 Madonna
# Actual Class: 48 Marg_Helgenberger 	 Prediction: 47 Madonna
# Actual Class: 49 Maria_Menounos 	 Prediction: 47 Madonna
# Actual Class: 49 Maria_Menounos 	 Prediction: 81 Rooney_Mara
# Actual Class: 49 Maria_Menounos 	 Prediction: 47 Madonna
# Actual Class: 49 Maria_Menounos 	 Prediction: 47 Madonna
# Actual Class: 49 Maria_Menounos 	 Prediction: 47 Madonna
# Actual Class: 49 Maria_Menounos 	 Prediction: 47 Madonna
# Actual Class: 49 Maria_Menounos 	 Prediction: 47 Madonna
# Actual Class: 49 Maria_Menounos 	 Prediction: 47 Madonna
# Actual Class: 49 Maria_Menounos 	 Prediction: 47 Madonna
# Actual Class: 49 Maria_Menounos 	 Prediction: 47 Madonna
# Actual Class: 50 Martin_Short 	 Prediction: 47 Madonna
# Actual Class: 50 Martin_Short 	 Prediction: 47 Madonna
# Actual Class: 50 Martin_Short 	 Prediction: 47 Madonna
# Actual Class: 50 Martin_Short 	 Prediction: 47 Madonna
# Actual Class: 50 Martin_Short 	 Prediction: 47 Madonna
# Actual Class: 50 Martin_Short 	 Prediction: 47 Madonna
# Actual Class: 50 Martin_Short 	 Prediction: 47 Madonna
# Actual Class: 50 Martin_Short 	 Prediction: 47 Madonna
# Actual Class: 50 Martin_Short 	 Prediction: 47 Madonna
# Actual Class: 50 Martin_Short 	 Prediction: 47 Madonna
# Actual Class: 51 Mary-Louise_Parker 	 Prediction: 47 Madonna
# Actual Class: 51 Mary-Louise_Parker 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 51 Mary-Louise_Parker 	 Prediction: 47 Madonna
# Actual Class: 51 Mary-Louise_Parker 	 Prediction: 47 Madonna
# Actual Class: 51 Mary-Louise_Parker 	 Prediction: 47 Madonna
# Actual Class: 51 Mary-Louise_Parker 	 Prediction: 47 Madonna
# Actual Class: 51 Mary-Louise_Parker 	 Prediction: 47 Madonna
# Actual Class: 51 Mary-Louise_Parker 	 Prediction: 47 Madonna
# Actual Class: 51 Mary-Louise_Parker 	 Prediction: 81 Rooney_Mara
# Actual Class: 51 Mary-Louise_Parker 	 Prediction: 47 Madonna
# Actual Class: 52 Mary_Elizabeth_Winstead 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 52 Mary_Elizabeth_Winstead 	 Prediction: 47 Madonna
# Actual Class: 52 Mary_Elizabeth_Winstead 	 Prediction: 47 Madonna
# Actual Class: 52 Mary_Elizabeth_Winstead 	 Prediction: 47 Madonna
# Actual Class: 52 Mary_Elizabeth_Winstead 	 Prediction: 47 Madonna
# Actual Class: 52 Mary_Elizabeth_Winstead 	 Prediction: 47 Madonna
# Actual Class: 52 Mary_Elizabeth_Winstead 	 Prediction: 81 Rooney_Mara
# Actual Class: 52 Mary_Elizabeth_Winstead 	 Prediction: 47 Madonna
# Actual Class: 52 Mary_Elizabeth_Winstead 	 Prediction: 47 Madonna
# Actual Class: 52 Mary_Elizabeth_Winstead 	 Prediction: 47 Madonna
# Actual Class: 53 Matt_Lanter 	 Prediction: 47 Madonna
# Actual Class: 53 Matt_Lanter 	 Prediction: 81 Rooney_Mara
# Actual Class: 53 Matt_Lanter 	 Prediction: 47 Madonna
# Actual Class: 53 Matt_Lanter 	 Prediction: 47 Madonna
# Actual Class: 53 Matt_Lanter 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 53 Matt_Lanter 	 Prediction: 47 Madonna
# Actual Class: 53 Matt_Lanter 	 Prediction: 47 Madonna
# Actual Class: 53 Matt_Lanter 	 Prediction: 81 Rooney_Mara
# Actual Class: 53 Matt_Lanter 	 Prediction: 47 Madonna
# Actual Class: 53 Matt_Lanter 	 Prediction: 47 Madonna
# Actual Class: 54 Matt_Smith 	 Prediction: 47 Madonna
# Actual Class: 54 Matt_Smith 	 Prediction: 81 Rooney_Mara
# Actual Class: 54 Matt_Smith 	 Prediction: 81 Rooney_Mara
# Actual Class: 54 Matt_Smith 	 Prediction: 47 Madonna
# Actual Class: 54 Matt_Smith 	 Prediction: 81 Rooney_Mara
# Actual Class: 54 Matt_Smith 	 Prediction: 47 Madonna
# Actual Class: 54 Matt_Smith 	 Prediction: 47 Madonna
# Actual Class: 54 Matt_Smith 	 Prediction: 47 Madonna
# Actual Class: 54 Matt_Smith 	 Prediction: 81 Rooney_Mara
# Actual Class: 54 Matt_Smith 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 55 Matthew_Fox 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 55 Matthew_Fox 	 Prediction: 47 Madonna
# Actual Class: 55 Matthew_Fox 	 Prediction: 47 Madonna
# Actual Class: 55 Matthew_Fox 	 Prediction: 81 Rooney_Mara
# Actual Class: 55 Matthew_Fox 	 Prediction: 47 Madonna
# Actual Class: 55 Matthew_Fox 	 Prediction: 81 Rooney_Mara
# Actual Class: 55 Matthew_Fox 	 Prediction: 47 Madonna
# Actual Class: 55 Matthew_Fox 	 Prediction: 47 Madonna
# Actual Class: 55 Matthew_Fox 	 Prediction: 47 Madonna
# Actual Class: 55 Matthew_Fox 	 Prediction: 81 Rooney_Mara
# Actual Class: 56 Max_Greenfield 	 Prediction: 81 Rooney_Mara
# Actual Class: 56 Max_Greenfield 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 56 Max_Greenfield 	 Prediction: 47 Madonna
# Actual Class: 56 Max_Greenfield 	 Prediction: 81 Rooney_Mara
# Actual Class: 56 Max_Greenfield 	 Prediction: 47 Madonna
# Actual Class: 56 Max_Greenfield 	 Prediction: 47 Madonna
# Actual Class: 56 Max_Greenfield 	 Prediction: 81 Rooney_Mara
# Actual Class: 56 Max_Greenfield 	 Prediction: 81 Rooney_Mara
# Actual Class: 56 Max_Greenfield 	 Prediction: 47 Madonna
# Actual Class: 56 Max_Greenfield 	 Prediction: 47 Madonna
# Actual Class: 57 Megan_Boone 	 Prediction: 81 Rooney_Mara
# Actual Class: 57 Megan_Boone 	 Prediction: 47 Madonna
# Actual Class: 57 Megan_Boone 	 Prediction: 47 Madonna
# Actual Class: 57 Megan_Boone 	 Prediction: 81 Rooney_Mara
# Actual Class: 57 Megan_Boone 	 Prediction: 47 Madonna
# Actual Class: 57 Megan_Boone 	 Prediction: 81 Rooney_Mara
# Actual Class: 57 Megan_Boone 	 Prediction: 81 Rooney_Mara
# Actual Class: 57 Megan_Boone 	 Prediction: 47 Madonna
# Actual Class: 57 Megan_Boone 	 Prediction: 81 Rooney_Mara
# Actual Class: 57 Megan_Boone 	 Prediction: 47 Madonna
# Actual Class: 58 Megan_Fox 	 Prediction: 47 Madonna
# Actual Class: 58 Megan_Fox 	 Prediction: 47 Madonna
# Actual Class: 58 Megan_Fox 	 Prediction: 47 Madonna
# Actual Class: 58 Megan_Fox 	 Prediction: 47 Madonna
# Actual Class: 58 Megan_Fox 	 Prediction: 47 Madonna
# Actual Class: 58 Megan_Fox 	 Prediction: 81 Rooney_Mara
# Actual Class: 58 Megan_Fox 	 Prediction: 81 Rooney_Mara
# Actual Class: 58 Megan_Fox 	 Prediction: 47 Madonna
# Actual Class: 58 Megan_Fox 	 Prediction: 47 Madonna
# Actual Class: 58 Megan_Fox 	 Prediction: 47 Madonna
# Actual Class: 59 Michael_J_Fox 	 Prediction: 47 Madonna
# Actual Class: 59 Michael_J_Fox 	 Prediction: 47 Madonna
# Actual Class: 59 Michael_J_Fox 	 Prediction: 47 Madonna
# Actual Class: 59 Michael_J_Fox 	 Prediction: 47 Madonna
# Actual Class: 59 Michael_J_Fox 	 Prediction: 81 Rooney_Mara
# Actual Class: 59 Michael_J_Fox 	 Prediction: 47 Madonna
# Actual Class: 59 Michael_J_Fox 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 59 Michael_J_Fox 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 59 Michael_J_Fox 	 Prediction: 47 Madonna
# Actual Class: 59 Michael_J_Fox 	 Prediction: 47 Madonna
# Actual Class: 60 Michael_Pena 	 Prediction: 47 Madonna
# Actual Class: 60 Michael_Pena 	 Prediction: 47 Madonna
# Actual Class: 60 Michael_Pena 	 Prediction: 81 Rooney_Mara
# Actual Class: 60 Michael_Pena 	 Prediction: 81 Rooney_Mara
# Actual Class: 60 Michael_Pena 	 Prediction: 81 Rooney_Mara
# Actual Class: 60 Michael_Pena 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 60 Michael_Pena 	 Prediction: 47 Madonna
# Actual Class: 60 Michael_Pena 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 60 Michael_Pena 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 60 Michael_Pena 	 Prediction: 47 Madonna
# Actual Class: 61 Michael_Weatherly 	 Prediction: 47 Madonna
# Actual Class: 61 Michael_Weatherly 	 Prediction: 47 Madonna
# Actual Class: 61 Michael_Weatherly 	 Prediction: 47 Madonna
# Actual Class: 61 Michael_Weatherly 	 Prediction: 81 Rooney_Mara
# Actual Class: 61 Michael_Weatherly 	 Prediction: 47 Madonna
# Actual Class: 61 Michael_Weatherly 	 Prediction: 81 Rooney_Mara
# Actual Class: 61 Michael_Weatherly 	 Prediction: 47 Madonna
# Actual Class: 61 Michael_Weatherly 	 Prediction: 47 Madonna
# Actual Class: 61 Michael_Weatherly 	 Prediction: 47 Madonna
# Actual Class: 61 Michael_Weatherly 	 Prediction: 47 Madonna
# Actual Class: 62 Michelle_Monaghan 	 Prediction: 47 Madonna
# Actual Class: 62 Michelle_Monaghan 	 Prediction: 81 Rooney_Mara
# Actual Class: 62 Michelle_Monaghan 	 Prediction: 47 Madonna
# Actual Class: 62 Michelle_Monaghan 	 Prediction: 47 Madonna
# Actual Class: 62 Michelle_Monaghan 	 Prediction: 47 Madonna
# Actual Class: 62 Michelle_Monaghan 	 Prediction: 81 Rooney_Mara
# Actual Class: 62 Michelle_Monaghan 	 Prediction: 81 Rooney_Mara
# Actual Class: 62 Michelle_Monaghan 	 Prediction: 47 Madonna
# Actual Class: 62 Michelle_Monaghan 	 Prediction: 81 Rooney_Mara
# Actual Class: 62 Michelle_Monaghan 	 Prediction: 47 Madonna
# Actual Class: 63 Mindy_Kaling 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 63 Mindy_Kaling 	 Prediction: 81 Rooney_Mara
# Actual Class: 63 Mindy_Kaling 	 Prediction: 47 Madonna
# Actual Class: 63 Mindy_Kaling 	 Prediction: 47 Madonna
# Actual Class: 63 Mindy_Kaling 	 Prediction: 47 Madonna
# Actual Class: 63 Mindy_Kaling 	 Prediction: 81 Rooney_Mara
# Actual Class: 63 Mindy_Kaling 	 Prediction: 47 Madonna
# Actual Class: 63 Mindy_Kaling 	 Prediction: 47 Madonna
# Actual Class: 63 Mindy_Kaling 	 Prediction: 47 Madonna
# Actual Class: 63 Mindy_Kaling 	 Prediction: 81 Rooney_Mara
# Actual Class: 64 Mira_Sorvino 	 Prediction: 47 Madonna
# Actual Class: 64 Mira_Sorvino 	 Prediction: 47 Madonna
# Actual Class: 64 Mira_Sorvino 	 Prediction: 47 Madonna
# Actual Class: 64 Mira_Sorvino 	 Prediction: 47 Madonna
# Actual Class: 64 Mira_Sorvino 	 Prediction: 47 Madonna
# Actual Class: 64 Mira_Sorvino 	 Prediction: 47 Madonna
# Actual Class: 64 Mira_Sorvino 	 Prediction: 47 Madonna
# Actual Class: 64 Mira_Sorvino 	 Prediction: 47 Madonna
# Actual Class: 64 Mira_Sorvino 	 Prediction: 47 Madonna
# Actual Class: 64 Mira_Sorvino 	 Prediction: 47 Madonna
# Actual Class: 65 Nathan_Fillion 	 Prediction: 81 Rooney_Mara
# Actual Class: 65 Nathan_Fillion 	 Prediction: 47 Madonna
# Actual Class: 65 Nathan_Fillion 	 Prediction: 47 Madonna
# Actual Class: 65 Nathan_Fillion 	 Prediction: 47 Madonna
# Actual Class: 65 Nathan_Fillion 	 Prediction: 47 Madonna
# Actual Class: 65 Nathan_Fillion 	 Prediction: 47 Madonna
# Actual Class: 65 Nathan_Fillion 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 65 Nathan_Fillion 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 65 Nathan_Fillion 	 Prediction: 47 Madonna
# Actual Class: 65 Nathan_Fillion 	 Prediction: 81 Rooney_Mara
# Actual Class: 66 Neal_McDonough 	 Prediction: 47 Madonna
# Actual Class: 66 Neal_McDonough 	 Prediction: 47 Madonna
# Actual Class: 66 Neal_McDonough 	 Prediction: 47 Madonna
# Actual Class: 66 Neal_McDonough 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 66 Neal_McDonough 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 66 Neal_McDonough 	 Prediction: 47 Madonna
# Actual Class: 66 Neal_McDonough 	 Prediction: 47 Madonna
# Actual Class: 66 Neal_McDonough 	 Prediction: 47 Madonna
# Actual Class: 66 Neal_McDonough 	 Prediction: 47 Madonna
# Actual Class: 66 Neal_McDonough 	 Prediction: 47 Madonna
# Actual Class: 67 Neil_Patrick_Harris 	 Prediction: 47 Madonna
# Actual Class: 67 Neil_Patrick_Harris 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 67 Neil_Patrick_Harris 	 Prediction: 81 Rooney_Mara
# Actual Class: 67 Neil_Patrick_Harris 	 Prediction: 47 Madonna
# Actual Class: 67 Neil_Patrick_Harris 	 Prediction: 47 Madonna
# Actual Class: 67 Neil_Patrick_Harris 	 Prediction: 47 Madonna
# Actual Class: 67 Neil_Patrick_Harris 	 Prediction: 47 Madonna
# Actual Class: 67 Neil_Patrick_Harris 	 Prediction: 47 Madonna
# Actual Class: 67 Neil_Patrick_Harris 	 Prediction: 47 Madonna
# Actual Class: 67 Neil_Patrick_Harris 	 Prediction: 47 Madonna
# Actual Class: 68 Nina_Dobrev 	 Prediction: 47 Madonna
# Actual Class: 68 Nina_Dobrev 	 Prediction: 47 Madonna
# Actual Class: 68 Nina_Dobrev 	 Prediction: 47 Madonna
# Actual Class: 68 Nina_Dobrev 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 68 Nina_Dobrev 	 Prediction: 47 Madonna
# Actual Class: 68 Nina_Dobrev 	 Prediction: 47 Madonna
# Actual Class: 68 Nina_Dobrev 	 Prediction: 47 Madonna
# Actual Class: 68 Nina_Dobrev 	 Prediction: 81 Rooney_Mara
# Actual Class: 68 Nina_Dobrev 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 68 Nina_Dobrev 	 Prediction: 47 Madonna
# Actual Class: 69 Octavia_Spencer 	 Prediction: 47 Madonna
# Actual Class: 69 Octavia_Spencer 	 Prediction: 47 Madonna
# Actual Class: 69 Octavia_Spencer 	 Prediction: 47 Madonna
# Actual Class: 69 Octavia_Spencer 	 Prediction: 47 Madonna
# Actual Class: 69 Octavia_Spencer 	 Prediction: 47 Madonna
# Actual Class: 69 Octavia_Spencer 	 Prediction: 47 Madonna
# Actual Class: 69 Octavia_Spencer 	 Prediction: 47 Madonna
# Actual Class: 69 Octavia_Spencer 	 Prediction: 81 Rooney_Mara
# Actual Class: 69 Octavia_Spencer 	 Prediction: 47 Madonna
# Actual Class: 69 Octavia_Spencer 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 70 Paris_Hilton 	 Prediction: 47 Madonna
# Actual Class: 70 Paris_Hilton 	 Prediction: 47 Madonna
# Actual Class: 70 Paris_Hilton 	 Prediction: 47 Madonna
# Actual Class: 70 Paris_Hilton 	 Prediction: 81 Rooney_Mara
# Actual Class: 70 Paris_Hilton 	 Prediction: 81 Rooney_Mara
# Actual Class: 70 Paris_Hilton 	 Prediction: 81 Rooney_Mara
# Actual Class: 70 Paris_Hilton 	 Prediction: 47 Madonna
# Actual Class: 70 Paris_Hilton 	 Prediction: 47 Madonna
# Actual Class: 70 Paris_Hilton 	 Prediction: 81 Rooney_Mara
# Actual Class: 70 Paris_Hilton 	 Prediction: 47 Madonna
# Actual Class: 71 Patrick_Swayze 	 Prediction: 47 Madonna
# Actual Class: 71 Patrick_Swayze 	 Prediction: 47 Madonna
# Actual Class: 71 Patrick_Swayze 	 Prediction: 47 Madonna
# Actual Class: 71 Patrick_Swayze 	 Prediction: 47 Madonna
# Actual Class: 71 Patrick_Swayze 	 Prediction: 47 Madonna
# Actual Class: 71 Patrick_Swayze 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 71 Patrick_Swayze 	 Prediction: 47 Madonna
# Actual Class: 71 Patrick_Swayze 	 Prediction: 47 Madonna
# Actual Class: 71 Patrick_Swayze 	 Prediction: 47 Madonna
# Actual Class: 71 Patrick_Swayze 	 Prediction: 47 Madonna
# Actual Class: 72 Peter_Facinelli 	 Prediction: 81 Rooney_Mara
# Actual Class: 72 Peter_Facinelli 	 Prediction: 81 Rooney_Mara
# Actual Class: 72 Peter_Facinelli 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 72 Peter_Facinelli 	 Prediction: 47 Madonna
# Actual Class: 72 Peter_Facinelli 	 Prediction: 47 Madonna
# Actual Class: 72 Peter_Facinelli 	 Prediction: 47 Madonna
# Actual Class: 72 Peter_Facinelli 	 Prediction: 47 Madonna
# Actual Class: 72 Peter_Facinelli 	 Prediction: 81 Rooney_Mara
# Actual Class: 72 Peter_Facinelli 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 72 Peter_Facinelli 	 Prediction: 47 Madonna
# Actual Class: 73 Rachael_Leigh_Cook 	 Prediction: 47 Madonna
# Actual Class: 73 Rachael_Leigh_Cook 	 Prediction: 47 Madonna
# Actual Class: 73 Rachael_Leigh_Cook 	 Prediction: 81 Rooney_Mara
# Actual Class: 73 Rachael_Leigh_Cook 	 Prediction: 47 Madonna
# Actual Class: 73 Rachael_Leigh_Cook 	 Prediction: 47 Madonna
# Actual Class: 73 Rachael_Leigh_Cook 	 Prediction: 81 Rooney_Mara
# Actual Class: 73 Rachael_Leigh_Cook 	 Prediction: 47 Madonna
# Actual Class: 73 Rachael_Leigh_Cook 	 Prediction: 47 Madonna
# Actual Class: 73 Rachael_Leigh_Cook 	 Prediction: 47 Madonna
# Actual Class: 73 Rachael_Leigh_Cook 	 Prediction: 47 Madonna
# Actual Class: 74 Rachel_Bilson 	 Prediction: 47 Madonna
# Actual Class: 74 Rachel_Bilson 	 Prediction: 47 Madonna
# Actual Class: 74 Rachel_Bilson 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 74 Rachel_Bilson 	 Prediction: 81 Rooney_Mara
# Actual Class: 74 Rachel_Bilson 	 Prediction: 47 Madonna
# Actual Class: 74 Rachel_Bilson 	 Prediction: 47 Madonna
# Actual Class: 74 Rachel_Bilson 	 Prediction: 47 Madonna
# Actual Class: 74 Rachel_Bilson 	 Prediction: 47 Madonna
# Actual Class: 74 Rachel_Bilson 	 Prediction: 47 Madonna
# Actual Class: 74 Rachel_Bilson 	 Prediction: 47 Madonna
# Actual Class: 75 Rachel_Nichols 	 Prediction: 47 Madonna
# Actual Class: 75 Rachel_Nichols 	 Prediction: 47 Madonna
# Actual Class: 75 Rachel_Nichols 	 Prediction: 81 Rooney_Mara
# Actual Class: 75 Rachel_Nichols 	 Prediction: 81 Rooney_Mara
# Actual Class: 75 Rachel_Nichols 	 Prediction: 47 Madonna
# Actual Class: 75 Rachel_Nichols 	 Prediction: 47 Madonna
# Actual Class: 75 Rachel_Nichols 	 Prediction: 47 Madonna
# Actual Class: 75 Rachel_Nichols 	 Prediction: 47 Madonna
# Actual Class: 75 Rachel_Nichols 	 Prediction: 47 Madonna
# Actual Class: 75 Rachel_Nichols 	 Prediction: 81 Rooney_Mara
# Actual Class: 76 Rachel_Weisz 	 Prediction: 47 Madonna
# Actual Class: 76 Rachel_Weisz 	 Prediction: 47 Madonna
# Actual Class: 76 Rachel_Weisz 	 Prediction: 47 Madonna
# Actual Class: 76 Rachel_Weisz 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 76 Rachel_Weisz 	 Prediction: 47 Madonna
# Actual Class: 76 Rachel_Weisz 	 Prediction: 47 Madonna
# Actual Class: 76 Rachel_Weisz 	 Prediction: 47 Madonna
# Actual Class: 76 Rachel_Weisz 	 Prediction: 47 Madonna
# Actual Class: 76 Rachel_Weisz 	 Prediction: 47 Madonna
# Actual Class: 76 Rachel_Weisz 	 Prediction: 47 Madonna
# Actual Class: 77 Robert_Downey_Jr 	 Prediction: 47 Madonna
# Actual Class: 77 Robert_Downey_Jr 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 77 Robert_Downey_Jr 	 Prediction: 47 Madonna
# Actual Class: 77 Robert_Downey_Jr 	 Prediction: 47 Madonna
# Actual Class: 77 Robert_Downey_Jr 	 Prediction: 81 Rooney_Mara
# Actual Class: 77 Robert_Downey_Jr 	 Prediction: 47 Madonna
# Actual Class: 77 Robert_Downey_Jr 	 Prediction: 47 Madonna
# Actual Class: 77 Robert_Downey_Jr 	 Prediction: 81 Rooney_Mara
# Actual Class: 77 Robert_Downey_Jr 	 Prediction: 81 Rooney_Mara
# Actual Class: 77 Robert_Downey_Jr 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 78 Robert_Duvall 	 Prediction: 47 Madonna
# Actual Class: 78 Robert_Duvall 	 Prediction: 47 Madonna
# Actual Class: 78 Robert_Duvall 	 Prediction: 81 Rooney_Mara
# Actual Class: 78 Robert_Duvall 	 Prediction: 47 Madonna
# Actual Class: 78 Robert_Duvall 	 Prediction: 81 Rooney_Mara
# Actual Class: 78 Robert_Duvall 	 Prediction: 47 Madonna
# Actual Class: 78 Robert_Duvall 	 Prediction: 47 Madonna
# Actual Class: 78 Robert_Duvall 	 Prediction: 47 Madonna
# Actual Class: 78 Robert_Duvall 	 Prediction: 47 Madonna
# Actual Class: 78 Robert_Duvall 	 Prediction: 81 Rooney_Mara
# Actual Class: 79 Robert_Redford 	 Prediction: 81 Rooney_Mara
# Actual Class: 79 Robert_Redford 	 Prediction: 81 Rooney_Mara
# Actual Class: 79 Robert_Redford 	 Prediction: 47 Madonna
# Actual Class: 79 Robert_Redford 	 Prediction: 47 Madonna
# Actual Class: 79 Robert_Redford 	 Prediction: 47 Madonna
# Actual Class: 79 Robert_Redford 	 Prediction: 47 Madonna
# Actual Class: 79 Robert_Redford 	 Prediction: 81 Rooney_Mara
# Actual Class: 79 Robert_Redford 	 Prediction: 47 Madonna
# Actual Class: 79 Robert_Redford 	 Prediction: 47 Madonna
# Actual Class: 79 Robert_Redford 	 Prediction: 47 Madonna
# Actual Class: 80 Robin_Wright 	 Prediction: 81 Rooney_Mara
# Actual Class: 80 Robin_Wright 	 Prediction: 47 Madonna
# Actual Class: 80 Robin_Wright 	 Prediction: 47 Madonna
# Actual Class: 80 Robin_Wright 	 Prediction: 47 Madonna
# Actual Class: 80 Robin_Wright 	 Prediction: 47 Madonna
# Actual Class: 80 Robin_Wright 	 Prediction: 47 Madonna
# Actual Class: 80 Robin_Wright 	 Prediction: 47 Madonna
# Actual Class: 80 Robin_Wright 	 Prediction: 81 Rooney_Mara
# Actual Class: 80 Robin_Wright 	 Prediction: 47 Madonna
# Actual Class: 80 Robin_Wright 	 Prediction: 47 Madonna
# Actual Class: 81 Rooney_Mara 	 Prediction: 47 Madonna
# Actual Class: 81 Rooney_Mara 	 Prediction: 81 Rooney_Mara
# Actual Class: 81 Rooney_Mara 	 Prediction: 81 Rooney_Mara
# Actual Class: 81 Rooney_Mara 	 Prediction: 47 Madonna
# Actual Class: 81 Rooney_Mara 	 Prediction: 47 Madonna
# Actual Class: 81 Rooney_Mara 	 Prediction: 81 Rooney_Mara
# Actual Class: 81 Rooney_Mara 	 Prediction: 81 Rooney_Mara
# Actual Class: 81 Rooney_Mara 	 Prediction: 47 Madonna
# Actual Class: 81 Rooney_Mara 	 Prediction: 81 Rooney_Mara
# Actual Class: 81 Rooney_Mara 	 Prediction: 81 Rooney_Mara
# Actual Class: 82 Russell_Crowe 	 Prediction: 47 Madonna
# Actual Class: 82 Russell_Crowe 	 Prediction: 47 Madonna
# Actual Class: 82 Russell_Crowe 	 Prediction: 47 Madonna
# Actual Class: 82 Russell_Crowe 	 Prediction: 47 Madonna
# Actual Class: 82 Russell_Crowe 	 Prediction: 47 Madonna
# Actual Class: 82 Russell_Crowe 	 Prediction: 81 Rooney_Mara
# Actual Class: 82 Russell_Crowe 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 82 Russell_Crowe 	 Prediction: 47 Madonna
# Actual Class: 82 Russell_Crowe 	 Prediction: 47 Madonna
# Actual Class: 82 Russell_Crowe 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 83 Ryan_Gosling 	 Prediction: 47 Madonna
# Actual Class: 83 Ryan_Gosling 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 83 Ryan_Gosling 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 83 Ryan_Gosling 	 Prediction: 47 Madonna
# Actual Class: 83 Ryan_Gosling 	 Prediction: 47 Madonna
# Actual Class: 83 Ryan_Gosling 	 Prediction: 47 Madonna
# Actual Class: 83 Ryan_Gosling 	 Prediction: 47 Madonna
# Actual Class: 83 Ryan_Gosling 	 Prediction: 81 Rooney_Mara
# Actual Class: 83 Ryan_Gosling 	 Prediction: 47 Madonna
# Actual Class: 83 Ryan_Gosling 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 84 Ryan_Seacrest 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 84 Ryan_Seacrest 	 Prediction: 47 Madonna
# Actual Class: 84 Ryan_Seacrest 	 Prediction: 81 Rooney_Mara
# Actual Class: 84 Ryan_Seacrest 	 Prediction: 81 Rooney_Mara
# Actual Class: 84 Ryan_Seacrest 	 Prediction: 47 Madonna
# Actual Class: 84 Ryan_Seacrest 	 Prediction: 47 Madonna
# Actual Class: 84 Ryan_Seacrest 	 Prediction: 47 Madonna
# Actual Class: 84 Ryan_Seacrest 	 Prediction: 47 Madonna
# Actual Class: 84 Ryan_Seacrest 	 Prediction: 81 Rooney_Mara
# Actual Class: 84 Ryan_Seacrest 	 Prediction: 47 Madonna
# Actual Class: 85 Sally_Field 	 Prediction: 81 Rooney_Mara
# Actual Class: 85 Sally_Field 	 Prediction: 47 Madonna
# Actual Class: 85 Sally_Field 	 Prediction: 47 Madonna
# Actual Class: 85 Sally_Field 	 Prediction: 47 Madonna
# Actual Class: 85 Sally_Field 	 Prediction: 47 Madonna
# Actual Class: 85 Sally_Field 	 Prediction: 47 Madonna
# Actual Class: 85 Sally_Field 	 Prediction: 47 Madonna
# Actual Class: 85 Sally_Field 	 Prediction: 47 Madonna
# Actual Class: 85 Sally_Field 	 Prediction: 47 Madonna
# Actual Class: 85 Sally_Field 	 Prediction: 47 Madonna
# Actual Class: 86 Sarah_Gadon 	 Prediction: 47 Madonna
# Actual Class: 86 Sarah_Gadon 	 Prediction: 47 Madonna
# Actual Class: 86 Sarah_Gadon 	 Prediction: 81 Rooney_Mara
# Actual Class: 86 Sarah_Gadon 	 Prediction: 81 Rooney_Mara
# Actual Class: 86 Sarah_Gadon 	 Prediction: 81 Rooney_Mara
# Actual Class: 86 Sarah_Gadon 	 Prediction: 47 Madonna
# Actual Class: 86 Sarah_Gadon 	 Prediction: 81 Rooney_Mara
# Actual Class: 86 Sarah_Gadon 	 Prediction: 47 Madonna
# Actual Class: 86 Sarah_Gadon 	 Prediction: 81 Rooney_Mara
# Actual Class: 86 Sarah_Gadon 	 Prediction: 47 Madonna
# Actual Class: 87 Sasha_Pieterse 	 Prediction: 47 Madonna
# Actual Class: 87 Sasha_Pieterse 	 Prediction: 47 Madonna
# Actual Class: 87 Sasha_Pieterse 	 Prediction: 81 Rooney_Mara
# Actual Class: 87 Sasha_Pieterse 	 Prediction: 47 Madonna
# Actual Class: 87 Sasha_Pieterse 	 Prediction: 47 Madonna
# Actual Class: 87 Sasha_Pieterse 	 Prediction: 47 Madonna
# Actual Class: 87 Sasha_Pieterse 	 Prediction: 47 Madonna
# Actual Class: 87 Sasha_Pieterse 	 Prediction: 47 Madonna
# Actual Class: 87 Sasha_Pieterse 	 Prediction: 47 Madonna
# Actual Class: 87 Sasha_Pieterse 	 Prediction: 81 Rooney_Mara
# Actual Class: 88 Seann_William_Scott 	 Prediction: 47 Madonna
# Actual Class: 88 Seann_William_Scott 	 Prediction: 47 Madonna
# Actual Class: 88 Seann_William_Scott 	 Prediction: 47 Madonna
# Actual Class: 88 Seann_William_Scott 	 Prediction: 81 Rooney_Mara
# Actual Class: 88 Seann_William_Scott 	 Prediction: 47 Madonna
# Actual Class: 88 Seann_William_Scott 	 Prediction: 47 Madonna
# Actual Class: 88 Seann_William_Scott 	 Prediction: 81 Rooney_Mara
# Actual Class: 88 Seann_William_Scott 	 Prediction: 47 Madonna
# Actual Class: 88 Seann_William_Scott 	 Prediction: 47 Madonna
# Actual Class: 88 Seann_William_Scott 	 Prediction: 47 Madonna
# Actual Class: 89 Selena_Gomez 	 Prediction: 47 Madonna
# Actual Class: 89 Selena_Gomez 	 Prediction: 81 Rooney_Mara
# Actual Class: 89 Selena_Gomez 	 Prediction: 47 Madonna
# Actual Class: 89 Selena_Gomez 	 Prediction: 81 Rooney_Mara
# Actual Class: 89 Selena_Gomez 	 Prediction: 47 Madonna
# Actual Class: 89 Selena_Gomez 	 Prediction: 47 Madonna
# Actual Class: 89 Selena_Gomez 	 Prediction: 47 Madonna
# Actual Class: 89 Selena_Gomez 	 Prediction: 47 Madonna
# Actual Class: 89 Selena_Gomez 	 Prediction: 81 Rooney_Mara
# Actual Class: 89 Selena_Gomez 	 Prediction: 81 Rooney_Mara
# Actual Class: 90 Shane_West 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 90 Shane_West 	 Prediction: 81 Rooney_Mara
# Actual Class: 90 Shane_West 	 Prediction: 47 Madonna
# Actual Class: 90 Shane_West 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 90 Shane_West 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 90 Shane_West 	 Prediction: 47 Madonna
# Actual Class: 90 Shane_West 	 Prediction: 47 Madonna
# Actual Class: 90 Shane_West 	 Prediction: 47 Madonna
# Actual Class: 90 Shane_West 	 Prediction: 47 Madonna
# Actual Class: 90 Shane_West 	 Prediction: 81 Rooney_Mara
# Actual Class: 91 Shannyn_Sossamon 	 Prediction: 47 Madonna
# Actual Class: 91 Shannyn_Sossamon 	 Prediction: 47 Madonna
# Actual Class: 91 Shannyn_Sossamon 	 Prediction: 47 Madonna
# Actual Class: 91 Shannyn_Sossamon 	 Prediction: 47 Madonna
# Actual Class: 91 Shannyn_Sossamon 	 Prediction: 47 Madonna
# Actual Class: 91 Shannyn_Sossamon 	 Prediction: 47 Madonna
# Actual Class: 91 Shannyn_Sossamon 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 91 Shannyn_Sossamon 	 Prediction: 47 Madonna
# Actual Class: 91 Shannyn_Sossamon 	 Prediction: 47 Madonna
# Actual Class: 91 Shannyn_Sossamon 	 Prediction: 47 Madonna
# Actual Class: 92 Sienna_Miller 	 Prediction: 81 Rooney_Mara
# Actual Class: 92 Sienna_Miller 	 Prediction: 81 Rooney_Mara
# Actual Class: 92 Sienna_Miller 	 Prediction: 81 Rooney_Mara
# Actual Class: 92 Sienna_Miller 	 Prediction: 81 Rooney_Mara
# Actual Class: 92 Sienna_Miller 	 Prediction: 47 Madonna
# Actual Class: 92 Sienna_Miller 	 Prediction: 47 Madonna
# Actual Class: 92 Sienna_Miller 	 Prediction: 81 Rooney_Mara
# Actual Class: 92 Sienna_Miller 	 Prediction: 81 Rooney_Mara
# Actual Class: 92 Sienna_Miller 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 92 Sienna_Miller 	 Prediction: 81 Rooney_Mara
# Actual Class: 93 Simon_Baker 	 Prediction: 81 Rooney_Mara
# Actual Class: 93 Simon_Baker 	 Prediction: 47 Madonna
# Actual Class: 93 Simon_Baker 	 Prediction: 47 Madonna
# Actual Class: 93 Simon_Baker 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 93 Simon_Baker 	 Prediction: 47 Madonna
# Actual Class: 93 Simon_Baker 	 Prediction: 47 Madonna
# Actual Class: 93 Simon_Baker 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 93 Simon_Baker 	 Prediction: 81 Rooney_Mara
# Actual Class: 93 Simon_Baker 	 Prediction: 47 Madonna
# Actual Class: 93 Simon_Baker 	 Prediction: 47 Madonna
# Actual Class: 94 Stephen_Dorff 	 Prediction: 47 Madonna
# Actual Class: 94 Stephen_Dorff 	 Prediction: 81 Rooney_Mara
# Actual Class: 94 Stephen_Dorff 	 Prediction: 47 Madonna
# Actual Class: 94 Stephen_Dorff 	 Prediction: 47 Madonna
# Actual Class: 94 Stephen_Dorff 	 Prediction: 47 Madonna
# Actual Class: 94 Stephen_Dorff 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 94 Stephen_Dorff 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 94 Stephen_Dorff 	 Prediction: 47 Madonna
# Actual Class: 94 Stephen_Dorff 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 94 Stephen_Dorff 	 Prediction: 81 Rooney_Mara
# Actual Class: 95 Ty_Burrell 	 Prediction: 47 Madonna
# Actual Class: 95 Ty_Burrell 	 Prediction: 47 Madonna
# Actual Class: 95 Ty_Burrell 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 95 Ty_Burrell 	 Prediction: 81 Rooney_Mara
# Actual Class: 95 Ty_Burrell 	 Prediction: 47 Madonna
# Actual Class: 95 Ty_Burrell 	 Prediction: 81 Rooney_Mara
# Actual Class: 95 Ty_Burrell 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 95 Ty_Burrell 	 Prediction: 47 Madonna
# Actual Class: 95 Ty_Burrell 	 Prediction: 47 Madonna
# Actual Class: 95 Ty_Burrell 	 Prediction: 47 Madonna
# Actual Class: 96 Tyler_Perry 	 Prediction: 47 Madonna
# Actual Class: 96 Tyler_Perry 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 96 Tyler_Perry 	 Prediction: 47 Madonna
# Actual Class: 96 Tyler_Perry 	 Prediction: 47 Madonna
# Actual Class: 96 Tyler_Perry 	 Prediction: 81 Rooney_Mara
# Actual Class: 96 Tyler_Perry 	 Prediction: 47 Madonna
# Actual Class: 96 Tyler_Perry 	 Prediction: 81 Rooney_Mara
# Actual Class: 96 Tyler_Perry 	 Prediction: 81 Rooney_Mara
# Actual Class: 96 Tyler_Perry 	 Prediction: 47 Madonna
# Actual Class: 96 Tyler_Perry 	 Prediction: 47 Madonna
# Actual Class: 97 Tyra_Banks 	 Prediction: 81 Rooney_Mara
# Actual Class: 97 Tyra_Banks 	 Prediction: 81 Rooney_Mara
# Actual Class: 97 Tyra_Banks 	 Prediction: 47 Madonna
# Actual Class: 97 Tyra_Banks 	 Prediction: 47 Madonna
# Actual Class: 97 Tyra_Banks 	 Prediction: 47 Madonna
# Actual Class: 97 Tyra_Banks 	 Prediction: 81 Rooney_Mara
# Actual Class: 97 Tyra_Banks 	 Prediction: 47 Madonna
# Actual Class: 97 Tyra_Banks 	 Prediction: 47 Madonna
# Actual Class: 97 Tyra_Banks 	 Prediction: 32 Jamie_Lee_Curtis
# Actual Class: 97 Tyra_Banks 	 Prediction: 47 Madonna
# Actual Class: 98 Zachary_Levi 	 Prediction: 47 Madonna
# Actual Class: 98 Zachary_Levi 	 Prediction: 47 Madonna
# Actual Class: 98 Zachary_Levi 	 Prediction: 47 Madonna
# Actual Class: 98 Zachary_Levi 	 Prediction: 81 Rooney_Mara
# Actual Class: 98 Zachary_Levi 	 Prediction: 47 Madonna
# Actual Class: 98 Zachary_Levi 	 Prediction: 81 Rooney_Mara
# Actual Class: 98 Zachary_Levi 	 Prediction: 81 Rooney_Mara
# Actual Class: 98 Zachary_Levi 	 Prediction: 47 Madonna
# Actual Class: 98 Zachary_Levi 	 Prediction: 81 Rooney_Mara
# Actual Class: 98 Zachary_Levi 	 Prediction: 47 Madonna
# Actual Class: 99 Zoe_Saldana 	 Prediction: 81 Rooney_Mara
# Actual Class: 99 Zoe_Saldana 	 Prediction: 81 Rooney_Mara
# Actual Class: 99 Zoe_Saldana 	 Prediction: 47 Madonna
# Actual Class: 99 Zoe_Saldana 	 Prediction: 47 Madonna
# Actual Class: 99 Zoe_Saldana 	 Prediction: 81 Rooney_Mara
# Actual Class: 99 Zoe_Saldana 	 Prediction: 47 Madonna
# Actual Class: 99 Zoe_Saldana 	 Prediction: 47 Madonna
# Actual Class: 99 Zoe_Saldana 	 Prediction: 47 Madonna
# Actual Class: 99 Zoe_Saldana 	 Prediction: 47 Madonna
# Actual Class: 99 Zoe_Saldana 	 Prediction: 81 Rooney_Mara
# Accuracy:  1.60%
